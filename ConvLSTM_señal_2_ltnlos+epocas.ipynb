# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import time
#A continuación se importan laas librerias necesarias para el entrenamiento de la red 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.layers import Activation
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from keras.layers import ConvLSTM2D
from keras.layers import Flatten

# %%
dataframe = pd.read_csv('/content/drive/My Drive/Mediciones en csv/LTNLOS CSV/potencia 2000-01-30 20_3A45_3A47 Antenna Horn Time 300[s] SwitchingBy 0 Horn 0 Omni 0 FIN_010.csv', header=None )
#llevar al dataframe a un arreglo de valores
dataset = dataframe.values
#dataset solo para la funcion senoidal
POT = dataset[0:len(dataset),1]
#POT = dataset
print(POT.shape)
plt.figure(figsize=[12,10])
plt.grid()
plt.plot(POT)
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.title("Datos reales", fontsize = 20)
# Out:
# (210865,)
# Text(0.5, 1.0, 'Datos reales')

# %% [markdown]
# # Nueva sección

# %%
#llevo la funcion a un arreglo de [lARGO DEL ARREGLO ,1] PARA ESCALAR LOS DATOS y que la red aprenda de mejor forma
POT2=POT.reshape(len(POT),1)
print(POT2.shape)
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
POT2 = scaler.fit_transform(POT2)
# Out:
# (210865, 1)

# %%
# divido la funcion y1 en arreglos para entrenar y probar la red
train_size = int(len(POT2) * 0.8)
test_size = len(POT2) - train_size
train, test = POT2[0:train_size,:], POT2[train_size:len(POT2),:]
print(len(train), len(test))
print(train.shape)
print(test.shape)
# Out:
# 168692 42173
# (168692, 1)
# (42173, 1)

# %%
# convertir un arreglo de valores en una matrix
def create_dataset(POT2, look_back=1):
    dataX, dataY = [], []
    for i in range(len(POT2)-look_back-1):
        a = POT2[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(POT2[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
# reshape dentro X=t and Y=t+1
look_back = 128
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
print(trainX.shape)
print(testX.shape)
print(trainY.shape)
print(testY.shape)
#print(trainX[0])
#print(trainY[0])
#print(trainX[1])
#print(trainY[1])
#print(trainX[2])
#print(trainY[3])
# Out:
# (168563, 128)
# (42044, 128)
# (168563,)
# (42044,)

# %%
#n_timesteps, n_features, n_outputs = trainX.shape[1], trainX.shape[2], trainy.shape[1]
# reshape into subsequences (samples, time steps, rows, cols, channels)
n_steps, n_length, n_features = 4, 32, 1
trainX = trainX.reshape((trainX.shape[0], n_steps, 1, n_length, n_features))
testX = testX.reshape((testX.shape[0], n_steps, 1, n_length, n_features))

# %%
model = Sequential()
model.add(ConvLSTM2D(filters=128, kernel_size=(1,3), return_sequences = True ,activation='relu', input_shape=(n_steps, 1, n_length, n_features)))
#model.add(ConvLSTM2D(filters=32, kernel_size=(1,3), input_shape=(n_steps, 1, n_length, n_features)))
model.add(Dropout(0.3))
model.add(ConvLSTM2D(filters=128, kernel_size=(1,3), activation='relu', input_shape=(n_steps, 1, n_length, n_features)))
#model.add(LSTM(input_shape = (None, None, 32, 1), output_dim= 128, return_sequences = True))
model.add(Dropout(0.3))
#model.add(LSTM(128))
#model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse', 'mae', 'mape'])
model.summary()
keras.utils.plot_model(model, 'my_first_model.png')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_lst_m2d_3 (ConvLSTM2D)  (None, 4, 1, 30, 128)     198656
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 1, 30, 128)     0
# _________________________________________________________________
# conv_lst_m2d_4 (ConvLSTM2D)  (None, 1, 28, 128)        393728
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1, 28, 128)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 3584)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 3585
# =================================================================
# Total params: 595,969
# Trainable params: 595,969
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
filepath="Checkpoint_mejores_pesos_señal_ltnlos_S2.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_mean_absolute_percentage_error', verbose=1, save_best_only=True, mode='min')
# simple early stopping
es = EarlyStopping(monitor='val_mean_absolute_percentage_error', mode='min', verbose=1, patience=5)

# %%
batch_size= 64 
epochs= 30
start = time.time()
History_ltnlos2 = model.fit(trainX, trainY,batch_size=batch_size, epochs= epochs, callbacks=[es, checkpoint] , validation_split=0.1)
print("> Compilation Time : ", time.time() - start)
# Out:
# Train on 151706 samples, validate on 16857 samples
# Epoch 1/30
# 151706/151706 [==============================] - 89s 586us/step - loss: 0.0072 - mean_squared_error: 0.0072 - mean_absolute_error: 0.0592 - mean_absolute_percentage_error: 11.2636 - val_loss: 0.0063 - val_mean_squared_error: 0.0063 - val_mean_absolute_error: 0.0615 - val_mean_absolute_percentage_error: 11.1124
#
# Epoch 00001: val_mean_absolute_percentage_error improved from inf to 11.11241, saving model to Checkpoint_mejores_pesos_señal_ltnlos_S2.hdf5
# Epoch 2/30
# 151706/151706 [==============================] - 80s 530us/step - loss: 0.0049 - mean_squared_error: 0.0049 - mean_absolute_error: 0.0496 - mean_absolute_percentage_error: 9.5503 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - val_mean_absolute_error: 0.0396 - val_mean_absolute_percentage_error: 7.8100
#
# Epoch 00002: val_mean_absolute_percentage_error improved from 11.11241 to 7.80996, saving model to Checkpoint_mejores_pesos_señal_ltnlos_S2.hdf5
# Epoch 3/30
# 151706/151706 [==============================] - 79s 521us/step - loss: 0.0041 - mean_squared_error: 0.0041 - mean_absolute_error: 0.0444 - mean_absolute_percentage_error: 8.6071 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0398 - val_mean_absolute_percentage_error: 7.7599
#
# Epoch 00003: val_mean_absolute_percentage_error improved from 7.80996 to 7.75993, saving model to Checkpoint_mejores_pesos_señal_ltnlos_S2.hdf5
# Epoch 4/30
# 151706/151706 [==============================] - 78s 513us/step - loss: 0.0039 - mean_squared_error: 0.0039 - mean_absolute_error: 0.0426 - mean_absolute_percentage_error: 8.2747 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0376 - val_mean_absolute_percentage_error: 7.7190
#
# Epoch 00004: val_mean_absolute_percentage_error improved from 7.75993 to 7.71899, saving model to Checkpoint_mejores_pesos_señal_ltnlos_S2.hdf5
# Epoch 5/30
# 151706/151706 [==============================] - 78s 511us/step - loss: 0.0037 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0416 - mean_absolute_percentage_error: 8.0816 - val_loss: 0.0029 - val_mean_squared_error: 0.0029 - val_mean_absolute_error: 0.0350 - val_mean_absolute_percentage_error: 7.0089
#
# Epoch 00005: val_mean_absolute_percentage_error improved from 7.71899 to 7.00889, saving model to Checkpoint_mejores_pesos_señal_ltnlos_S2.hdf5
# Epoch 6/30
# 151706/151706 [==============================] - 78s 517us/step - loss: 0.0036 - mean_squared_error: 0.0036 - mean_absolute_error: 0.0411 - mean_absolute_percentage_error: 7.9915 - val_loss: 0.0029 - val_mean_squared_error: 0.0029 - val_mean_absolute_error: 0.0348 - val_mean_absolute_percentage_error: 7.0286
#
# Epoch 00006: val_mean_absolute_percentage_error did not improve from 7.00889
# Epoch 7/30
# 151706/151706 [==============================] - 77s 510us/step - loss: 0.0036 - mean_squared_error: 0.0036 - mean_absolute_error: 0.0405 - mean_absolute_percentage_error: 7.8884 - val_loss: 0.0030 - val_mean_squared_error: 0.0030 - val_mean_absolute_error: 0.0359 - val_mean_absolute_percentage_error: 7.2839
#
# Epoch 00007: val_mean_absolute_percentage_error did not improve from 7.00889
# Epoch 8/30
# 151706/151706 [==============================] - 77s 509us/step - loss: 0.0035 - mean_squared_error: 0.0035 - mean_absolute_error: 0.0402 - mean_absolute_percentage_error: 7.8251 - val_loss: 0.0028 - val_mean_squared_error: 0.0028 - val_mean_absolute_error: 0.0340 - val_mean_absolute_percentage_error: 6.8804
#
# Epoch 00008: val_mean_absolute_percentage_error improved from 7.00889 to 6.88036, saving model to Checkpoint_mejores_pesos_señal_ltnlos_S2.hdf5
# Epoch 9/30
# 151706/151706 [==============================] - 77s 505us/step - loss: 0.0035 - mean_squared_error: 0.0035 - mean_absolute_error: 0.0399 - mean_absolute_percentage_error: 7.7707 - val_loss: 0.0031 - val_mean_squared_error: 0.0031 - val_mean_absolute_error: 0.0392 - val_mean_absolute_percentage_error: 7.4573
#
# Epoch 00009: val_mean_absolute_percentage_error did not improve from 6.88036
# Epoch 10/30
# 151706/151706 [==============================] - 77s 508us/step - loss: 0.0035 - mean_squared_error: 0.0035 - mean_absolute_error: 0.0396 - mean_absolute_percentage_error: 7.7112 - val_loss: 0.0028 - val_mean_squared_error: 0.0028 - val_mean_absolute_error: 0.0346 - val_mean_absolute_percentage_error: 6.8281
#
# Epoch 00010: val_mean_absolute_percentage_error improved from 6.88036 to 6.82806, saving model to Checkpoint_mejores_pesos_señal_ltnlos_S2.hdf5
# Epoch 11/30
# 151706/151706 [==============================] - 78s 512us/step - loss: 0.0034 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0393 - mean_absolute_percentage_error: 7.6805 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - val_mean_absolute_error: 0.0338 - val_mean_absolute_percentage_error: 6.8222
#
# Epoch 00011: val_mean_absolute_percentage_error improved from 6.82806 to 6.82216, saving model to Checkpoint_mejores_pesos_señal_ltnlos_S2.hdf5
# Epoch 12/30
# 151706/151706 [==============================] - 78s 511us/step - loss: 0.0034 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0391 - mean_absolute_percentage_error: 7.6478 - val_loss: 0.0028 - val_mean_squared_error: 0.0028 - val_mean_absolute_error: 0.0347 - val_mean_absolute_percentage_error: 7.0321
#
# Epoch 00012: val_mean_absolute_percentage_error did not improve from 6.82216
# Epoch 13/30
# 151706/151706 [==============================] - 77s 506us/step - loss: 0.0034 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0392 - mean_absolute_percentage_error: 7.6372 - val_loss: 0.0028 - val_mean_squared_error: 0.0028 - val_mean_absolute_error: 0.0346 - val_mean_absolute_percentage_error: 6.8375
#
# Epoch 00013: val_mean_absolute_percentage_error did not improve from 6.82216
# Epoch 14/30
# 151706/151706 [==============================] - 77s 504us/step - loss: 0.0034 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0390 - mean_absolute_percentage_error: 7.6146 - val_loss: 0.0028 - val_mean_squared_error: 0.0028 - val_mean_absolute_error: 0.0341 - val_mean_absolute_percentage_error: 6.9378
#
# Epoch 00014: val_mean_absolute_percentage_error did not improve from 6.82216
# Epoch 15/30
# 151706/151706 [==============================] - 77s 508us/step - loss: 0.0034 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0389 - mean_absolute_percentage_error: 7.5933 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - val_mean_absolute_error: 0.0332 - val_mean_absolute_percentage_error: 6.6616
#
# Epoch 00015: val_mean_absolute_percentage_error improved from 6.82216 to 6.66161, saving model to Checkpoint_mejores_pesos_señal_ltnlos_S2.hdf5
# Epoch 16/30
# 151706/151706 [==============================] - 76s 504us/step - loss: 0.0034 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0388 - mean_absolute_percentage_error: 7.5867 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - val_mean_absolute_error: 0.0331 - val_mean_absolute_percentage_error: 6.7289
#
# Epoch 00016: val_mean_absolute_percentage_error did not improve from 6.66161
# Epoch 17/30
# 151706/151706 [==============================] - 77s 505us/step - loss: 0.0034 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0387 - mean_absolute_percentage_error: 7.5509 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - val_mean_absolute_error: 0.0335 - val_mean_absolute_percentage_error: 6.6117
#
# Epoch 00017: val_mean_absolute_percentage_error improved from 6.66161 to 6.61170, saving model to Checkpoint_mejores_pesos_señal_ltnlos_S2.hdf5
# Epoch 18/30
# 151706/151706 [==============================] - 78s 511us/step - loss: 0.0033 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0386 - mean_absolute_percentage_error: 7.5516 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - val_mean_absolute_error: 0.0344 - val_mean_absolute_percentage_error: 6.7505
#
# Epoch 00018: val_mean_absolute_percentage_error did not improve from 6.61170
# Epoch 19/30
# 151706/151706 [==============================] - 78s 514us/step - loss: 0.0033 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0385 - mean_absolute_percentage_error: 7.5135 - val_loss: 0.0028 - val_mean_squared_error: 0.0028 - val_mean_absolute_error: 0.0355 - val_mean_absolute_percentage_error: 6.8845
#
# Epoch 00019: val_mean_absolute_percentage_error did not improve from 6.61170
# Epoch 20/30
# 151706/151706 [==============================] - 79s 522us/step - loss: 0.0033 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0384 - mean_absolute_percentage_error: 7.5099 - val_loss: 0.0028 - val_mean_squared_error: 0.0028 - val_mean_absolute_error: 0.0353 - val_mean_absolute_percentage_error: 6.8906
#
# Epoch 00020: val_mean_absolute_percentage_error did not improve from 6.61170
# Epoch 21/30
# 151706/151706 [==============================] - 78s 513us/step - loss: 0.0033 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0384 - mean_absolute_percentage_error: 7.4927 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - val_mean_absolute_error: 0.0337 - val_mean_absolute_percentage_error: 6.7638
#
# Epoch 00021: val_mean_absolute_percentage_error did not improve from 6.61170
# Epoch 22/30
# 151706/151706 [==============================] - 79s 523us/step - loss: 0.0033 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0383 - mean_absolute_percentage_error: 7.4853 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - val_mean_absolute_error: 0.0333 - val_mean_absolute_percentage_error: 6.5972
#
# Epoch 00022: val_mean_absolute_percentage_error improved from 6.61170 to 6.59723, saving model to Checkpoint_mejores_pesos_señal_ltnlos_S2.hdf5
# Epoch 23/30
# 151706/151706 [==============================] - 80s 527us/step - loss: 0.0033 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0383 - mean_absolute_percentage_error: 7.4877 - val_loss: 0.0028 - val_mean_squared_error: 0.0028 - val_mean_absolute_error: 0.0374 - val_mean_absolute_percentage_error: 7.2306
#
# Epoch 00023: val_mean_absolute_percentage_error did not improve from 6.59723
# Epoch 24/30
# 151706/151706 [==============================] - 79s 521us/step - loss: 0.0033 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0383 - mean_absolute_percentage_error: 7.4783 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - val_mean_absolute_error: 0.0333 - val_mean_absolute_percentage_error: 6.6804
#
# Epoch 00024: val_mean_absolute_percentage_error did not improve from 6.59723
# Epoch 25/30
# 151706/151706 [==============================] - 78s 516us/step - loss: 0.0033 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0382 - mean_absolute_percentage_error: 7.4619 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - val_mean_absolute_error: 0.0348 - val_mean_absolute_percentage_error: 6.7322
#
# Epoch 00025: val_mean_absolute_percentage_error did not improve from 6.59723
# Epoch 26/30
# 151706/151706 [==============================] - 79s 517us/step - loss: 0.0033 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0382 - mean_absolute_percentage_error: 7.4545 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - val_mean_absolute_error: 0.0338 - val_mean_absolute_percentage_error: 6.7248
#
# Epoch 00026: val_mean_absolute_percentage_error did not improve from 6.59723
# Epoch 27/30
# 151706/151706 [==============================] - 78s 516us/step - loss: 0.0033 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0382 - mean_absolute_percentage_error: 7.4569 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - val_mean_absolute_error: 0.0352 - val_mean_absolute_percentage_error: 6.8703
#
# Epoch 00027: val_mean_absolute_percentage_error did not improve from 6.59723
# Epoch 00027: early stopping
# > Compilation Time :  2117.57159781456

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model_ltnlos_señal2.json", "w") as json_file:
    json_file.write(model_json)

# %%
import pickle

pickle_out = open("History_ltnlos2.pickle","wb")
pickle.dump(History_ltnlos2, pickle_out)
pickle_out.close()

# %%
import pickle 

pickle_in = open("History_ltnlos2.pickle","rb")
History_saved = pickle.load(pickle_in)

# %%
History = History_saved

# %%
# plot metrics
#plt.figure(figsize=[8,8])
plt.plot(History.history['mean_squared_error'], label='mse')
plt.plot(History.history['val_mean_squared_error'], label= 'validación_mse')
plt.xlabel("epocas",fontsize = 16)
plt.ylabel("loss",fontsize = 16)
plt.legend(framealpha=1, frameon=True)

# %%
plt.plot(History.history['mean_absolute_error'], label='mae')
plt.plot(History.history['val_mean_absolute_error'], label= 'validación_mae')
plt.xlabel("epocas",fontsize = 16)
plt.ylabel("loss",fontsize = 16)
plt.legend(framealpha=1, frameon=True)

# %%
#History.history['mean_absolute_percentage_error']

# %%
plt.plot(History.history['mean_absolute_percentage_error'], label= 'mape')
plt.plot(History.history['val_mean_absolute_percentage_error'], label= 'validación_mape')
plt.xlabel("epocas",fontsize = 16)
plt.ylabel("loss",fontsize = 16)
plt.legend(framealpha=1, frameon=True)

# %%
# predicciones de los valores de prueba
prediccion_test = model.predict(testX)
prediccion_test = scaler.inverse_transform(prediccion_test)
#actuals = test_y
valor_real_test = scaler.inverse_transform([testY])
valor_real_test= valor_real_test.reshape(len(prediccion_test),1)
#prediccion de los valores de entrenamiento
aprendido=model.predict(trainX)
aprendido_train=scaler.inverse_transform(aprendido)
reales_train=scaler.inverse_transform([trainY])
reales_train=scaler.inverse_transform([trainY])
reales_train=reales_train.reshape(len(aprendido),1)
###################################################
mse_aprendido=mean_squared_error(reales_train,aprendido_train)
mse_test=mean_squared_error(valor_real_test,prediccion_test)
print('Train Mean square Error:', mse_aprendido)
print('Test Mean square Error:', mse_test)
#######################################################
rmse_train=math.sqrt(mse_aprendido)
rmse_test=math.sqrt(mse_test)
print('Train Root Mean Squared Error:', rmse_train)
print('Test Root Mean Squared Error:', rmse_test)
# Out:
# Train Mean square Error: 8.038042474069812
# Test Mean square Error: 4.796559145050688
# Train Root Mean Squared Error: 2.8351441716550876
# Test Root Mean Squared Error: 2.1901048251283974

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
#mape train
mean_absolute_percentage_error(reales_train,aprendido_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# inf

# %%
#mape test
mean_absolute_percentage_error(valor_real_test,prediccion_test)
# Out:
# 6.378562948025801

# %%
def smape(y_true, y_pred):
    denominator = (np.abs(y_true) + np.abs(y_pred))
    diff = np.abs(y_true - y_pred) / denominator
    diff[denominator == 0] = 0.0
    return 200 * np.mean(diff)

# %%
smape(reales_train,aprendido_train)
# Out:
# 10.510840818035966

# %%
smape(valor_real_test,prediccion_test)
# Out:
# 6.242657076621967

# %%
# plot entrenamiento
plt.figure(figsize=[12,12])
plt.plot(reales_train, label='Datos reales')
plt.plot(aprendido_train, label= 'predicciones aprendido')
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.legend(framealpha=1, frameon=True, loc='upper right')

# %%
# plot test
plt.figure(figsize=[12,12])
plt.plot(valor_real_test, label='Datos reales')
plt.plot(prediccion_test , label= 'predicciones test')
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.legend(framealpha=1, frameon=True, loc='upper right')

# %%
# plot test
plt.figure(figsize=[12,12])
plt.plot(valor_real_test[0:100], label='Datos reales')
plt.plot(prediccion_test[0:100] , label= 'predicciones test')
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.legend(framealpha=1, frameon=True, loc='upper right')

# %%
acc = abs(prediccion_test-valor_real_test)
porc_error = (acc / abs(valor_real_test)) * 100
mostrar = valor_real_test, prediccion_test, acc, porc_error
Tabla_arr = np.array(mostrar)
Tabla = np.transpose(Tabla_arr)
Tabla=Tabla.reshape(len(acc), -1)
Tabla_df = pd.DataFrame(Tabla, columns=['Datos predichos','Datos reales','Error','Error porcentual'])
Tabla_df
# Out:
#        Datos predichos  Datos reales      Error  Error porcentual
# 0               -23.76    -24.127684   0.367684          1.547490
# 1               -23.47    -24.007509   0.537509          2.290197
# 2               -23.32    -23.819994   0.499994          2.144056
# 3               -23.62    -23.826736   0.206736          0.875260
# 4               -23.76    -24.089600   0.329600          1.387204
# ...                ...           ...        ...               ...
# 42039           -18.89    -19.843170   0.953170          5.045898
# 42040           -16.68    -17.205105   0.525105          3.148110
# 42041           -18.30    -20.219624   1.919624         10.489746
# 42042           -34.69    -19.836912  14.853088         42.816627
# 42043           -19.63    -21.790487   2.160487         11.006048
#
# [42044 rows x 4 columns]

# %%
import seaborn as sns

# %%
aprendido_red=aprendido_train[:,0]
rial=reales_train[:,0]
testing=valor_real_test[:,0]
prediccion=prediccion_test[:,0]

# %%
sns.kdeplot(aprendido_red, cumulative=True)
sns.kdeplot(rial, cumulative=True)

# %%
err_apre=aprendido_train-reales_train
err_2=err_apre[:,0]
sns.kdeplot(err_2, cumulative=True)

# %%
sns.kdeplot(testing, cumulative=True)
sns.kdeplot(prediccion, cumulative=True)

# %%
err=prediccion_test-valor_real_test
err_1=err[:,0]
sns.kdeplot(err_1, cumulative=True)

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(POT2)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(aprendido_train)+look_back, :] = aprendido_train
# shift test predictions for plotting
testPredictPlot = np.empty_like(POT2)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(aprendido_train)+(look_back*2)+1:len(POT2)-1, :] = prediccion_test
# plot baseline and predictions
plt.figure(figsize=[12,12])
plt.plot((POT))
plt.plot(trainPredictPlot, color="red", )
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.plot(testPredictPlot, color="green")
plt.title("Predicciones de lo aprendido en rojo y verde en prueba", fontsize = 20)
plt.grid()
plt.show()

# %%
adqw=trainPredictPlot+testPredictPlot

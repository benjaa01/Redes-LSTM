# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import time
#A continuación se importan laas librerias necesarias para el entrenamiento de la red 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.layers import Activation
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from keras.layers import ConvLSTM2D
from keras.layers import Flatten
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.

# %%
dataframe = pd.read_csv('/content/drive/My Drive/LSTM /Mediciones en csv/HTLOS CSV/potencia 2000-01-03 21_3A11_3A34 Antenna Horn Time 300[s] SwitchingBy 0 Horn 0 Omni 0 ING-AU_033.csv', header=None )
#llevar al dataframe a un arreglo de valores
dataset = dataframe.values
#dataset solo para la funcion senoidal
POT = dataset[0:len(dataset),1]
#POT = dataset
print(POT.shape)
plt.figure(figsize=[12,10])
plt.grid()
plt.plot(POT)
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.title("Datos reales", fontsize = 20)
# Out:
# (210108,)
# Text(0.5, 1.0, 'Datos reales')

# %% [markdown]
# # Nueva sección

# %%
#llevo la funcion a un arreglo de [lARGO DEL ARREGLO ,1] PARA ESCALAR LOS DATOS y que la red aprenda de mejor forma
POT2=POT.reshape(len(POT),1)
print(POT2.shape)
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
POT2 = scaler.fit_transform(POT2)
# Out:
# (210108, 1)

# %%
# divido la funcion y1 en arreglos para entrenar y probar la red
train_size = int(len(POT2) * 0.8)
test_size = len(POT2) - train_size
train, test = POT2[0:train_size,:], POT2[train_size:len(POT2),:]
print(len(train), len(test))
print(train.shape)
print(test.shape)
# Out:
# 168086 42022
# (168086, 1)
# (42022, 1)

# %%
# convertir un arreglo de valores en una matrix
def create_dataset(POT2, look_back=1):
    dataX, dataY = [], []
    for i in range(len(POT2)-look_back-1):
        a = POT2[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(POT2[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
# reshape dentro X=t and Y=t+1
look_back = 128
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
print(trainX.shape)
print(testX.shape)
print(trainY.shape)
print(testY.shape)
#print(trainX[0])
#print(trainY[0])
#print(trainX[1])
#print(trainY[1])
#print(trainX[2])
#print(trainY[3])
# Out:
# (167957, 128)
# (41893, 128)
# (167957,)
# (41893,)

# %%
#n_timesteps, n_features, n_outputs = trainX.shape[1], trainX.shape[2], trainy.shape[1]
# reshape into subsequences (samples, time steps, rows, cols, channels)
n_steps, n_length, n_features = 4, 32, 1
trainX = trainX.reshape((trainX.shape[0], n_steps, 1, n_length, n_features))
testX = testX.reshape((testX.shape[0], n_steps, 1, n_length, n_features))

# %%
model = Sequential()
model.add(ConvLSTM2D(filters=128, kernel_size=(1,3), return_sequences = True ,activation='relu', input_shape=(n_steps, 1, n_length, n_features)))
#model.add(ConvLSTM2D(filters=32, kernel_size=(1,3), input_shape=(n_steps, 1, n_length, n_features)))
model.add(Dropout(0.3))
model.add(ConvLSTM2D(filters=128, kernel_size=(1,3), activation='relu', input_shape=(n_steps, 1, n_length, n_features)))
#model.add(LSTM(input_shape = (None, None, 32, 1), output_dim= 128, return_sequences = True))
model.add(Dropout(0.3))
#model.add(LSTM(128))
#model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse', 'mae', 'mape'])
model.summary()
keras.utils.plot_model(model, 'my_first_model.png')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_lst_m2d_5 (ConvLSTM2D)  (None, 4, 1, 30, 128)     198656
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 4, 1, 30, 128)     0
# _________________________________________________________________
# conv_lst_m2d_6 (ConvLSTM2D)  (None, 1, 28, 128)        393728
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1, 28, 128)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 3584)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 3585
# =================================================================
# Total params: 595,969
# Trainable params: 595,969
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
filepath="Checkpoint_mejores_pesos_señal_htlos_S1.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_mean_absolute_percentage_error', verbose=1, save_best_only=True, mode='min')
# simple early stopping
es = EarlyStopping(monitor='val_mean_absolute_percentage_error', mode='min', verbose=1, patience=5)

# %%
batch_size= 64 
epochs= 30
start = time.time()
History_htlos1 = model.fit(trainX, trainY,batch_size=batch_size, epochs= epochs, callbacks=[es, checkpoint] , validation_split=0.1)
print("> Compilation Time : ", time.time() - start)
# Out:
# Train on 151161 samples, validate on 16796 samples
# Epoch 1/30
# 151161/151161 [==============================] - 114s 755us/step - loss: 0.0035 - mean_squared_error: 0.0035 - mean_absolute_error: 0.0328 - mean_absolute_percentage_error: 3466.1278 - val_loss: 0.0010 - val_mean_squared_error: 0.0010 - val_mean_absolute_error: 0.0208 - val_mean_absolute_percentage_error: 2.8659
#
# Epoch 00001: val_mean_absolute_percentage_error improved from inf to 2.86587, saving model to Checkpoint_mejores_pesos_señal_htlos_S1.hdf5
# Epoch 2/30
# 151161/151161 [==============================] - 106s 702us/step - loss: 9.7776e-04 - mean_squared_error: 9.7776e-04 - mean_absolute_error: 0.0217 - mean_absolute_percentage_error: 2841.2860 - val_loss: 5.7041e-04 - val_mean_squared_error: 5.7041e-04 - val_mean_absolute_error: 0.0136 - val_mean_absolute_percentage_error: 1.9697
#
# Epoch 00002: val_mean_absolute_percentage_error improved from 2.86587 to 1.96969, saving model to Checkpoint_mejores_pesos_señal_htlos_S1.hdf5
# Epoch 3/30
# 151161/151161 [==============================] - 107s 709us/step - loss: 7.9876e-04 - mean_squared_error: 7.9876e-04 - mean_absolute_error: 0.0194 - mean_absolute_percentage_error: 2676.2761 - val_loss: 6.3853e-04 - val_mean_squared_error: 6.3853e-04 - val_mean_absolute_error: 0.0176 - val_mean_absolute_percentage_error: 2.3825
#
# Epoch 00003: val_mean_absolute_percentage_error did not improve from 1.96969
# Epoch 4/30
# 151161/151161 [==============================] - 107s 707us/step - loss: 6.6023e-04 - mean_squared_error: 6.6023e-04 - mean_absolute_error: 0.0176 - mean_absolute_percentage_error: 3160.7057 - val_loss: 5.0665e-04 - val_mean_squared_error: 5.0665e-04 - val_mean_absolute_error: 0.0163 - val_mean_absolute_percentage_error: 2.1960
#
# Epoch 00004: val_mean_absolute_percentage_error did not improve from 1.96969
# Epoch 5/30
# 151161/151161 [==============================] - 107s 707us/step - loss: 5.3501e-04 - mean_squared_error: 5.3501e-04 - mean_absolute_error: 0.0159 - mean_absolute_percentage_error: 2506.2879 - val_loss: 2.9331e-04 - val_mean_squared_error: 2.9331e-04 - val_mean_absolute_error: 0.0099 - val_mean_absolute_percentage_error: 1.4184
#
# Epoch 00005: val_mean_absolute_percentage_error improved from 1.96969 to 1.41837, saving model to Checkpoint_mejores_pesos_señal_htlos_S1.hdf5
# Epoch 6/30
# 151161/151161 [==============================] - 107s 708us/step - loss: 4.4018e-04 - mean_squared_error: 4.4018e-04 - mean_absolute_error: 0.0143 - mean_absolute_percentage_error: 1744.7822 - val_loss: 2.8755e-04 - val_mean_squared_error: 2.8755e-04 - val_mean_absolute_error: 0.0117 - val_mean_absolute_percentage_error: 1.6041
#
# Epoch 00006: val_mean_absolute_percentage_error did not improve from 1.41837
# Epoch 7/30
# 151161/151161 [==============================] - 107s 709us/step - loss: 3.8281e-04 - mean_squared_error: 3.8281e-04 - mean_absolute_error: 0.0133 - mean_absolute_percentage_error: 2458.9541 - val_loss: 4.3199e-04 - val_mean_squared_error: 4.3199e-04 - val_mean_absolute_error: 0.0167 - val_mean_absolute_percentage_error: 2.1816
#
# Epoch 00007: val_mean_absolute_percentage_error did not improve from 1.41837
# Epoch 8/30
# 151161/151161 [==============================] - 107s 707us/step - loss: 3.3576e-04 - mean_squared_error: 3.3576e-04 - mean_absolute_error: 0.0123 - mean_absolute_percentage_error: 1756.3624 - val_loss: 2.9475e-04 - val_mean_squared_error: 2.9475e-04 - val_mean_absolute_error: 0.0124 - val_mean_absolute_percentage_error: 1.6756
#
# Epoch 00008: val_mean_absolute_percentage_error did not improve from 1.41837
# Epoch 9/30
# 151161/151161 [==============================] - 106s 704us/step - loss: 3.0115e-04 - mean_squared_error: 3.0115e-04 - mean_absolute_error: 0.0116 - mean_absolute_percentage_error: 2304.7583 - val_loss: 2.0722e-04 - val_mean_squared_error: 2.0722e-04 - val_mean_absolute_error: 0.0093 - val_mean_absolute_percentage_error: 1.2823
#
# Epoch 00009: val_mean_absolute_percentage_error improved from 1.41837 to 1.28227, saving model to Checkpoint_mejores_pesos_señal_htlos_S1.hdf5
# Epoch 10/30
# 151161/151161 [==============================] - 106s 703us/step - loss: 2.8565e-04 - mean_squared_error: 2.8565e-04 - mean_absolute_error: 0.0111 - mean_absolute_percentage_error: 1338.3973 - val_loss: 2.2110e-04 - val_mean_squared_error: 2.2110e-04 - val_mean_absolute_error: 0.0100 - val_mean_absolute_percentage_error: 1.3702
#
# Epoch 00010: val_mean_absolute_percentage_error did not improve from 1.28227
# Epoch 11/30
# 151161/151161 [==============================] - 106s 703us/step - loss: 2.6398e-04 - mean_squared_error: 2.6398e-04 - mean_absolute_error: 0.0105 - mean_absolute_percentage_error: 2504.9709 - val_loss: 2.0089e-04 - val_mean_squared_error: 2.0089e-04 - val_mean_absolute_error: 0.0095 - val_mean_absolute_percentage_error: 1.3074
#
# Epoch 00011: val_mean_absolute_percentage_error did not improve from 1.28227
# Epoch 12/30
# 151161/151161 [==============================] - 106s 704us/step - loss: 2.4426e-04 - mean_squared_error: 2.4426e-04 - mean_absolute_error: 0.0101 - mean_absolute_percentage_error: 999.6945 - val_loss: 1.9070e-04 - val_mean_squared_error: 1.9070e-04 - val_mean_absolute_error: 0.0083 - val_mean_absolute_percentage_error: 1.1758
#
# Epoch 00012: val_mean_absolute_percentage_error improved from 1.28227 to 1.17580, saving model to Checkpoint_mejores_pesos_señal_htlos_S1.hdf5
# Epoch 13/30
# 151161/151161 [==============================] - 106s 704us/step - loss: 2.3522e-04 - mean_squared_error: 2.3522e-04 - mean_absolute_error: 0.0097 - mean_absolute_percentage_error: 2435.8800 - val_loss: 1.6632e-04 - val_mean_squared_error: 1.6632e-04 - val_mean_absolute_error: 0.0079 - val_mean_absolute_percentage_error: 1.1292
#
# Epoch 00013: val_mean_absolute_percentage_error improved from 1.17580 to 1.12922, saving model to Checkpoint_mejores_pesos_señal_htlos_S1.hdf5
# Epoch 14/30
# 151161/151161 [==============================] - 106s 703us/step - loss: 2.3203e-04 - mean_squared_error: 2.3203e-04 - mean_absolute_error: 0.0096 - mean_absolute_percentage_error: 2624.2664 - val_loss: 1.7642e-04 - val_mean_squared_error: 1.7642e-04 - val_mean_absolute_error: 0.0084 - val_mean_absolute_percentage_error: 1.1891
#
# Epoch 00014: val_mean_absolute_percentage_error did not improve from 1.12922
# Epoch 15/30
# 151161/151161 [==============================] - 107s 705us/step - loss: 2.2376e-04 - mean_squared_error: 2.2376e-04 - mean_absolute_error: 0.0094 - mean_absolute_percentage_error: 1266.6787 - val_loss: 1.5935e-04 - val_mean_squared_error: 1.5935e-04 - val_mean_absolute_error: 0.0067 - val_mean_absolute_percentage_error: 1.0082
#
# Epoch 00015: val_mean_absolute_percentage_error improved from 1.12922 to 1.00823, saving model to Checkpoint_mejores_pesos_señal_htlos_S1.hdf5
# Epoch 16/30
# 151161/151161 [==============================] - 108s 711us/step - loss: 2.1492e-04 - mean_squared_error: 2.1492e-04 - mean_absolute_error: 0.0092 - mean_absolute_percentage_error: 2601.9932 - val_loss: 1.5142e-04 - val_mean_squared_error: 1.5142e-04 - val_mean_absolute_error: 0.0066 - val_mean_absolute_percentage_error: 0.9812
#
# Epoch 00016: val_mean_absolute_percentage_error improved from 1.00823 to 0.98118, saving model to Checkpoint_mejores_pesos_señal_htlos_S1.hdf5
# Epoch 17/30
# 151161/151161 [==============================] - 107s 707us/step - loss: 2.1115e-04 - mean_squared_error: 2.1115e-04 - mean_absolute_error: 0.0091 - mean_absolute_percentage_error: 1250.7084 - val_loss: 1.5791e-04 - val_mean_squared_error: 1.5791e-04 - val_mean_absolute_error: 0.0078 - val_mean_absolute_percentage_error: 1.0952
#
# Epoch 00017: val_mean_absolute_percentage_error did not improve from 0.98118
# Epoch 18/30
# 151161/151161 [==============================] - 107s 705us/step - loss: 2.1306e-04 - mean_squared_error: 2.1306e-04 - mean_absolute_error: 0.0091 - mean_absolute_percentage_error: 2071.4579 - val_loss: 1.5158e-04 - val_mean_squared_error: 1.5158e-04 - val_mean_absolute_error: 0.0070 - val_mean_absolute_percentage_error: 1.0179
#
# Epoch 00018: val_mean_absolute_percentage_error did not improve from 0.98118
# Epoch 19/30
# 151161/151161 [==============================] - 107s 706us/step - loss: 2.0956e-04 - mean_squared_error: 2.0956e-04 - mean_absolute_error: 0.0089 - mean_absolute_percentage_error: 1525.8229 - val_loss: 1.4951e-04 - val_mean_squared_error: 1.4951e-04 - val_mean_absolute_error: 0.0064 - val_mean_absolute_percentage_error: 0.9708
#
# Epoch 00019: val_mean_absolute_percentage_error improved from 0.98118 to 0.97084, saving model to Checkpoint_mejores_pesos_señal_htlos_S1.hdf5
# Epoch 20/30
# 151161/151161 [==============================] - 107s 707us/step - loss: 2.0126e-04 - mean_squared_error: 2.0126e-04 - mean_absolute_error: 0.0088 - mean_absolute_percentage_error: 2162.6637 - val_loss: 1.4024e-04 - val_mean_squared_error: 1.4024e-04 - val_mean_absolute_error: 0.0063 - val_mean_absolute_percentage_error: 0.9425
#
# Epoch 00020: val_mean_absolute_percentage_error improved from 0.97084 to 0.94255, saving model to Checkpoint_mejores_pesos_señal_htlos_S1.hdf5
# Epoch 21/30
# 151161/151161 [==============================] - 107s 706us/step - loss: 1.9827e-04 - mean_squared_error: 1.9827e-04 - mean_absolute_error: 0.0087 - mean_absolute_percentage_error: 1103.1625 - val_loss: 1.5612e-04 - val_mean_squared_error: 1.5612e-04 - val_mean_absolute_error: 0.0081 - val_mean_absolute_percentage_error: 1.1245
#
# Epoch 00021: val_mean_absolute_percentage_error did not improve from 0.94255
# Epoch 22/30
# 151161/151161 [==============================] - 107s 705us/step - loss: 1.9564e-04 - mean_squared_error: 1.9564e-04 - mean_absolute_error: 0.0086 - mean_absolute_percentage_error: 1014.5970 - val_loss: 1.6104e-04 - val_mean_squared_error: 1.6104e-04 - val_mean_absolute_error: 0.0068 - val_mean_absolute_percentage_error: 1.0070
#
# Epoch 00022: val_mean_absolute_percentage_error did not improve from 0.94255
# Epoch 23/30
# 151161/151161 [==============================] - 107s 706us/step - loss: 1.9771e-04 - mean_squared_error: 1.9771e-04 - mean_absolute_error: 0.0087 - mean_absolute_percentage_error: 1622.1727 - val_loss: 1.5353e-04 - val_mean_squared_error: 1.5353e-04 - val_mean_absolute_error: 0.0066 - val_mean_absolute_percentage_error: 0.9818
#
# Epoch 00023: val_mean_absolute_percentage_error did not improve from 0.94255
# Epoch 24/30
# 151161/151161 [==============================] - 107s 706us/step - loss: 1.9444e-04 - mean_squared_error: 1.9444e-04 - mean_absolute_error: 0.0086 - mean_absolute_percentage_error: 977.5309 - val_loss: 1.4823e-04 - val_mean_squared_error: 1.4823e-04 - val_mean_absolute_error: 0.0065 - val_mean_absolute_percentage_error: 0.9746
#
# Epoch 00024: val_mean_absolute_percentage_error did not improve from 0.94255
# Epoch 25/30
# 151161/151161 [==============================] - 107s 705us/step - loss: 1.9591e-04 - mean_squared_error: 1.9591e-04 - mean_absolute_error: 0.0086 - mean_absolute_percentage_error: 2442.8388 - val_loss: 1.6803e-04 - val_mean_squared_error: 1.6803e-04 - val_mean_absolute_error: 0.0081 - val_mean_absolute_percentage_error: 1.1527
#
# Epoch 00025: val_mean_absolute_percentage_error did not improve from 0.94255
# Epoch 00025: early stopping
# > Compilation Time :  2677.397219657898

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model_htlos_señal1.json", "w") as json_file:
    json_file.write(model_json)

# %%
import pickle

pickle_out = open("History_htlos1.pickle","wb")
pickle.dump(History_htlos1, pickle_out)
pickle_out.close()

# %%
import pickle 

pickle_in = open("History_htlos1.pickle","rb")
History_saved = pickle.load(pickle_in)

# %%
History = History_saved

# %%
# plot metrics
#plt.figure(figsize=[8,8])
plt.plot(History.history['mean_squared_error'], label='mse')
plt.plot(History.history['val_mean_squared_error'], label= 'validación_mse')
plt.xlabel("epocas",fontsize = 16)
plt.ylabel("loss",fontsize = 16)
plt.legend(framealpha=1, frameon=True)

# %%
plt.plot(History.history['mean_absolute_error'], label='mae')
plt.plot(History.history['val_mean_absolute_error'], label= 'validación_mae')
plt.xlabel("epocas",fontsize = 16)
plt.ylabel("loss",fontsize = 16)
plt.legend(framealpha=1, frameon=True)

# %%
#History.history['mean_absolute_percentage_error']

# %%
plt.plot(History.history['mean_absolute_percentage_error'], label= 'mape')
plt.plot(History.history['val_mean_absolute_percentage_error'], label= 'validación_mape')
plt.xlabel("epocas",fontsize = 16)
plt.ylabel("loss",fontsize = 16)
plt.legend(framealpha=1, frameon=True)

# %%
# predicciones de los valores de prueba
prediccion_test = model.predict(testX)
prediccion_test = scaler.inverse_transform(prediccion_test)
#actuals = test_y
valor_real_test = scaler.inverse_transform([testY])
valor_real_test= valor_real_test.reshape(len(prediccion_test),1)
#prediccion de los valores de entrenamiento
aprendido=model.predict(trainX)
aprendido_train=scaler.inverse_transform(aprendido)
reales_train=scaler.inverse_transform([trainY])
reales_train=scaler.inverse_transform([trainY])
reales_train=reales_train.reshape(len(aprendido),1)
###################################################
mse_aprendido=mean_squared_error(reales_train,aprendido_train)
mse_test=mean_squared_error(valor_real_test,prediccion_test)
print('Train Mean square Error:', mse_aprendido)
print('Test Mean square Error:', mse_test)
#######################################################
rmse_train=math.sqrt(mse_aprendido)
rmse_test=math.sqrt(mse_test)
print('Train Root Mean Squared Error:', rmse_train)
print('Test Root Mean Squared Error:', rmse_test)
# Out:
# Train Mean square Error: 0.3251312535916766
# Test Mean square Error: 0.3934028409967213
# Train Root Mean Squared Error: 0.5702028179443491
# Test Root Mean Squared Error: 0.6272183359857405

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
#mape train
mean_absolute_percentage_error(reales_train,aprendido_train)
# Out:
# 2.892292306339944

# %%
#mape test
mean_absolute_percentage_error(valor_real_test,prediccion_test)
# Out:
# 3.2034695138727316

# %%
def smape(y_true, y_pred):
    denominator = (np.abs(y_true) + np.abs(y_pred))
    diff = np.abs(y_true - y_pred) / denominator
    diff[denominator == 0] = 0.0
    return 200 * np.mean(diff)

# %%
smape(reales_train,aprendido_train)
# Out:
# 2.9446030421781164

# %%
smape(valor_real_test,prediccion_test)
# Out:
# 3.264768805010365

# %%
# plot entrenamiento
plt.figure(figsize=[12,12])
plt.plot(reales_train, label='Datos reales')
plt.plot(aprendido_train, label= 'predicciones aprendido')
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.legend(framealpha=1, frameon=True, loc='upper right')

# %%
# plot test
plt.figure(figsize=[12,12])
plt.plot(valor_real_test, label='Datos reales')
plt.plot(prediccion_test , label= 'predicciones test')
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.legend(framealpha=1, frameon=True, loc='upper right')

# %%
# plot test
plt.figure(figsize=[12,12])
plt.plot(valor_real_test[24500:25000], label='Datos reales')
plt.plot(prediccion_test[24500:25000] , label= 'predicciones test')
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.legend(framealpha=1, frameon=True, loc='upper right')

# %%
acc = abs(prediccion_test-valor_real_test)
porc_error = (acc / abs(valor_real_test)) * 100
mostrar = valor_real_test, prediccion_test, acc, porc_error
Tabla_arr = np.array(mostrar)
Tabla = np.transpose(Tabla_arr)
Tabla=Tabla.reshape(len(acc), -1)
Tabla_df = pd.DataFrame(Tabla, columns=['Datos predichos','Datos reales','Error','Error porcentual'])
Tabla_df
# Out:
#        Datos predichos  Datos reales     Error  Error porcentual
# 0               -15.20    -14.983330  0.216670          1.425462
# 1               -15.50    -15.127185  0.372815          2.405259
# 2               -15.35    -15.458885  0.108885          0.709350
# 3               -15.06    -15.361798  0.301798          2.003973
# 4               -15.35    -15.063034  0.286966          1.869485
# ...                ...           ...       ...               ...
# 41888            -8.41     -8.324082  0.085918          1.021613
# 41889            -8.27     -8.299403  0.029403          0.355540
# 41890            -8.12     -8.187670  0.067670          0.833371
# 41891            -8.12     -8.051603  0.068397          0.842324
# 41892            -7.97     -8.021413  0.051413          0.645080
#
# [41893 rows x 4 columns]

# %%
import seaborn as sns

# %%
aprendido_red=aprendido_train[:,0]
rial=reales_train[:,0]
testing=valor_real_test[:,0]
prediccion=prediccion_test[:,0]

# %%
sns.kdeplot(aprendido_red, cumulative=True)
sns.kdeplot(rial, cumulative=True)

# %%
sns.kdeplot(testing, cumulative=True)
sns.kdeplot(prediccion, cumulative=True)

# %%
err=prediccion_test-valor_real_test
err_1=err[:,0]
sns.kdeplot(err_1, cumulative=True)

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(POT2)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(aprendido_train)+look_back, :] = aprendido_train
# shift test predictions for plotting
testPredictPlot = np.empty_like(POT2)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(aprendido_train)+(look_back*2)+1:len(POT2)-1, :] = prediccion_test
# plot baseline and predictions
plt.figure(figsize=[12,12])
plt.plot((POT))
plt.plot(trainPredictPlot, color="red", )
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.plot(testPredictPlot, color="green")
plt.title("Predicciones de lo aprendido en rojo y verde en prueba", fontsize = 20)
plt.grid()
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import time
#A continuación se importan laas librerias necesarias para el entrenamiento de la red 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.layers import Activation
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from keras.layers import ConvLSTM2D
from keras.layers import Flatten
from keras.optimizers import SGD, Adam
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.

# %%
dataframe = pd.read_csv('/content/drive/My Drive/LSTM /Mediciones en csv/HTNLOS CSV/potencia 2000-01-02 19_3A27_3A19 Antenna Horn Time 300[s] SwitchingBy 0 Horn 0 Omni 0 ING-AU_025.csv', header=None )
#llevar al dataframe a un arreglo de valores
dataset = dataframe.values
#dataset solo para la funcion senoidal
POT = dataset[0:len(dataset),1]
#POT = dataset
print(POT.shape)
plt.figure(figsize=[12,10])
plt.grid()
plt.plot(POT)
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.title("Datos reales", fontsize = 20)
# Out:
# (210584,)
# Text(0.5, 1.0, 'Datos reales')

# %% [markdown]
# # Nueva sección

# %%
#llevo la funcion a un arreglo de [lARGO DEL ARREGLO ,1] PARA ESCALAR LOS DATOS y que la red aprenda de mejor forma
POT2=POT.reshape(len(POT),1)
print(POT2.shape)
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
POT2 = scaler.fit_transform(POT2)
# Out:
# (210584, 1)

# %%
# divido la funcion y1 en arreglos para entrenar y probar la red
train_size = int(len(POT2) * 0.8)
test_size = len(POT2) - train_size
train, test = POT2[0:train_size,:], POT2[train_size:len(POT2),:]
print(len(train), len(test))
print(train.shape)
print(test.shape)
# Out:
# 168467 42117
# (168467, 1)
# (42117, 1)

# %%
# convertir un arreglo de valores en una matrix
def create_dataset(POT2, look_back=1):
    dataX, dataY = [], []
    for i in range(len(POT2)-look_back-1):
        a = POT2[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(POT2[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
# reshape dentro X=t and Y=t+1
look_back = 128
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
print(trainX.shape)
print(testX.shape)
print(trainY.shape)
print(testY.shape)
#print(trainX[0])
#print(trainY[0])
#print(trainX[1])
#print(trainY[1])
#print(trainX[2])
#print(trainY[3])
# Out:
# (168338, 128)
# (41988, 128)
# (168338,)
# (41988,)

# %%
# reshape a la entrada [samples, time steps, features] que es necesario para la red lstm
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
print(trainX.shape)
print(testX.shape)
# Out:
# (168338, 1, 128)
# (41988, 1, 128)

# %%
# create and fit the LSTM network
model = Sequential()

model.add(LSTM(256, activation = 'relu',return_sequences=True,input_shape=( 1, look_back)))
model.add(LSTM(128,return_sequences=True))
model.add(LSTM(64))
model.add(Dropout(0.2))
model.add(Dense(64))
model.add(Dense(32))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam',metrics=['mape','mse','mae'])
model.summary()
keras.utils.plot_model(model, 'my_first_model.png')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 1, 256)            394240
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1, 128)            197120
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 647,041
# Trainable params: 647,041
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
filepath="Checkpoint_mejores_pesos_señal_htnlos_S2_lstm_stacked.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_mean_absolute_percentage_error', verbose=1, save_best_only=True, mode='min')
# simple early stopping
es = EarlyStopping(monitor='val_mean_absolute_percentage_error', mode='min', verbose=1, patience=5)

# %%
batch_size= 32 
epochs= 30
start = time.time()
History_htnlos2_lstm_stacked = model.fit(trainX, trainY,batch_size=batch_size, epochs= epochs, callbacks=[es, checkpoint] , validation_split=0.1)
print("> Compilation Time : ", time.time() - start)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 151504 samples, validate on 16834 samples
# Epoch 1/30
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 151504/151504 [==============================] - 90s 593us/step - loss: 0.0042 - mean_absolute_percentage_error: 3027.7261 - mean_squared_error: 0.0042 - mean_absolute_error: 0.0434 - val_loss: 0.0031 - val_mean_absolute_percentage_error: 5.7223 - val_mean_squared_error: 0.0031 - val_mean_absolute_error: 0.0374
#
# Epoch 00001: val_mean_absolute_percentage_error improved from inf to 5.72231, saving model to Checkpoint_mejores_pesos_señal_htnlos_S2_lstm_stacked.hdf5
# Epoch 2/30
# 151504/151504 [==============================] - 78s 517us/step - loss: 0.0028 - mean_absolute_percentage_error: 3165.5252 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0358 - val_loss: 0.0031 - val_mean_absolute_percentage_error: 5.6480 - val_mean_squared_error: 0.0031 - val_mean_absolute_error: 0.0365
#
# Epoch 00002: val_mean_absolute_percentage_error improved from 5.72231 to 5.64803, saving model to Checkpoint_mejores_pesos_señal_htnlos_S2_lstm_stacked.hdf5
# Epoch 3/30
# 151504/151504 [==============================] - 78s 517us/step - loss: 0.0026 - mean_absolute_percentage_error: 2720.2825 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0344 - val_loss: 0.0031 - val_mean_absolute_percentage_error: 5.8143 - val_mean_squared_error: 0.0031 - val_mean_absolute_error: 0.0391
#
# Epoch 00003: val_mean_absolute_percentage_error did not improve from 5.64803
# Epoch 4/30
# 151504/151504 [==============================] - 79s 519us/step - loss: 0.0025 - mean_absolute_percentage_error: 3049.9535 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0334 - val_loss: 0.0041 - val_mean_absolute_percentage_error: 7.0891 - val_mean_squared_error: 0.0041 - val_mean_absolute_error: 0.0464
#
# Epoch 00004: val_mean_absolute_percentage_error did not improve from 5.64803
# Epoch 5/30
# 151504/151504 [==============================] - 79s 518us/step - loss: 0.0025 - mean_absolute_percentage_error: 2890.8962 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0330 - val_loss: 0.0028 - val_mean_absolute_percentage_error: 5.3295 - val_mean_squared_error: 0.0028 - val_mean_absolute_error: 0.0350
#
# Epoch 00005: val_mean_absolute_percentage_error improved from 5.64803 to 5.32950, saving model to Checkpoint_mejores_pesos_señal_htnlos_S2_lstm_stacked.hdf5
# Epoch 6/30
# 151504/151504 [==============================] - 78s 518us/step - loss: 0.0024 - mean_absolute_percentage_error: 3044.5818 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0322 - val_loss: 0.0032 - val_mean_absolute_percentage_error: 5.8845 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0381
#
# Epoch 00006: val_mean_absolute_percentage_error did not improve from 5.32950
# Epoch 7/30
# 151504/151504 [==============================] - 78s 516us/step - loss: 0.0024 - mean_absolute_percentage_error: 2794.9624 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0322 - val_loss: 0.0028 - val_mean_absolute_percentage_error: 5.2024 - val_mean_squared_error: 0.0028 - val_mean_absolute_error: 0.0337
#
# Epoch 00007: val_mean_absolute_percentage_error improved from 5.32950 to 5.20243, saving model to Checkpoint_mejores_pesos_señal_htnlos_S2_lstm_stacked.hdf5
# Epoch 8/30
# 151504/151504 [==============================] - 78s 516us/step - loss: 0.0024 - mean_absolute_percentage_error: 2726.4616 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0318 - val_loss: 0.0029 - val_mean_absolute_percentage_error: 5.3554 - val_mean_squared_error: 0.0029 - val_mean_absolute_error: 0.0356
#
# Epoch 00008: val_mean_absolute_percentage_error did not improve from 5.20243
# Epoch 9/30
# 151504/151504 [==============================] - 78s 517us/step - loss: 0.0024 - mean_absolute_percentage_error: 2720.0624 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0318 - val_loss: 0.0027 - val_mean_absolute_percentage_error: 5.1351 - val_mean_squared_error: 0.0027 - val_mean_absolute_error: 0.0336
#
# Epoch 00009: val_mean_absolute_percentage_error improved from 5.20243 to 5.13507, saving model to Checkpoint_mejores_pesos_señal_htnlos_S2_lstm_stacked.hdf5
# Epoch 10/30
# 151504/151504 [==============================] - 78s 513us/step - loss: 0.0023 - mean_absolute_percentage_error: 2762.3031 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0313 - val_loss: 0.0029 - val_mean_absolute_percentage_error: 5.3700 - val_mean_squared_error: 0.0029 - val_mean_absolute_error: 0.0345
#
# Epoch 00010: val_mean_absolute_percentage_error did not improve from 5.13507
# Epoch 11/30
# 151504/151504 [==============================] - 78s 515us/step - loss: 0.0023 - mean_absolute_percentage_error: 2699.3117 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0314 - val_loss: 0.0028 - val_mean_absolute_percentage_error: 5.5071 - val_mean_squared_error: 0.0028 - val_mean_absolute_error: 0.0368
#
# Epoch 00011: val_mean_absolute_percentage_error did not improve from 5.13507
# Epoch 12/30
# 151504/151504 [==============================] - 78s 515us/step - loss: 0.0023 - mean_absolute_percentage_error: 2887.4484 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0313 - val_loss: 0.0040 - val_mean_absolute_percentage_error: 7.2013 - val_mean_squared_error: 0.0040 - val_mean_absolute_error: 0.0504
#
# Epoch 00012: val_mean_absolute_percentage_error did not improve from 5.13507
# Epoch 13/30
# 151504/151504 [==============================] - 78s 516us/step - loss: 0.0023 - mean_absolute_percentage_error: 3010.1550 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0309 - val_loss: 0.0029 - val_mean_absolute_percentage_error: 5.5076 - val_mean_squared_error: 0.0029 - val_mean_absolute_error: 0.0369
#
# Epoch 00013: val_mean_absolute_percentage_error did not improve from 5.13507
# Epoch 14/30
# 151504/151504 [==============================] - 79s 519us/step - loss: 0.0023 - mean_absolute_percentage_error: 3003.3145 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0309 - val_loss: 0.0030 - val_mean_absolute_percentage_error: 5.5114 - val_mean_squared_error: 0.0030 - val_mean_absolute_error: 0.0370
#
# Epoch 00014: val_mean_absolute_percentage_error did not improve from 5.13507
# Epoch 00014: early stopping
# > Compilation Time :  1111.0793526172638

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model_htnlos_señal2_lstm_stacked.json", "w") as json_file:
    json_file.write(model_json)

# %%
import pickle

pickle_out = open("History_htnlos2_lstm_stacked.pickle","wb")
pickle.dump(History_htnlos2_lstm_stacked, pickle_out)
pickle_out.close()

# %%
import pickle 

pickle_in = open("History_htnlos2_lstm_stacked.pickle","rb")
History_saved = pickle.load(pickle_in)

# %%
History = History_saved

# %%
# plot metrics
#plt.figure(figsize=[8,8])
plt.plot(History.history['mean_squared_error'], label='mse')
plt.plot(History.history['val_mean_squared_error'], label= 'validación_mse')
plt.xlabel("epocas",fontsize = 16)
plt.ylabel("loss",fontsize = 16)
plt.legend(framealpha=1, frameon=True)

# %%
plt.plot(History.history['mean_absolute_error'], label='mae')
plt.plot(History.history['val_mean_absolute_error'], label= 'validación_mae')
plt.xlabel("epocas",fontsize = 16)
plt.ylabel("loss",fontsize = 16)
plt.legend(framealpha=1, frameon=True)

# %%
#History.history['mean_absolute_percentage_error']

# %%
plt.plot(History.history['mean_absolute_percentage_error'], label= 'mape')
plt.plot(History.history['val_mean_absolute_percentage_error'], label= 'validación_mape')
plt.xlabel("epocas",fontsize = 16)
plt.ylabel("loss",fontsize = 16)
plt.legend(framealpha=1, frameon=True)

# %%
# predicciones de los valores de prueba
prediccion_test = model.predict(testX)
prediccion_test = scaler.inverse_transform(prediccion_test)
#actuals = test_y
valor_real_test = scaler.inverse_transform([testY])
valor_real_test= valor_real_test.reshape(len(prediccion_test),1)
#prediccion de los valores de entrenamiento
aprendido=model.predict(trainX)
aprendido_train=scaler.inverse_transform(aprendido)
reales_train=scaler.inverse_transform([trainY])
reales_train=scaler.inverse_transform([trainY])
reales_train=reales_train.reshape(len(aprendido),1)
###################################################
mse_aprendido=mean_squared_error(reales_train,aprendido_train)
mse_test=mean_squared_error(valor_real_test,prediccion_test)
print('Train Mean square Error:', mse_aprendido)
print('Test Mean square Error:', mse_test)
#######################################################
rmse_train=math.sqrt(mse_aprendido)
rmse_test=math.sqrt(mse_test)
print('Train Root Mean Squared Error:', rmse_train)
print('Test Root Mean Squared Error:', rmse_test)
# Out:
# Train Mean square Error: 3.935335226451112
# Test Mean square Error: 2.4801811112145926
# Train Root Mean Squared Error: 1.983767936642568
# Test Root Mean Squared Error: 1.5748590766206965

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
#mape train
mean_absolute_percentage_error(reales_train,aprendido_train)
# Out:
# 6.333691054513807

# %%
#mape test
mean_absolute_percentage_error(valor_real_test,prediccion_test)
# Out:
# 5.429717237452626

# %%
def smape(y_true, y_pred):
    denominator = (np.abs(y_true) + np.abs(y_pred))
    diff = np.abs(y_true - y_pred) / denominator
    diff[denominator == 0] = 0.0
    return 200 * np.mean(diff)

# %%
smape(reales_train,aprendido_train)
# Out:
# 6.14746794408268

# %%
smape(valor_real_test,prediccion_test)
# Out:
# 5.269034091027698

# %%
# plot entrenamiento
plt.figure(figsize=[12,12])
plt.plot(reales_train, label='Datos reales')
plt.plot(aprendido_train, label= 'predicciones aprendido')
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.legend(framealpha=1, frameon=True, loc='upper right')

# %%
# plot test
plt.figure(figsize=[12,12])
plt.plot(valor_real_test, label='Datos reales')
plt.plot(prediccion_test , label= 'predicciones test')
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.legend(framealpha=1, frameon=True, loc='upper right')

# %%
# plot test
plt.figure(figsize=[12,12])
plt.plot(valor_real_test[10200:10500], label='Datos reales')
plt.plot(prediccion_test[10200:10500], label= 'predicciones test')
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.legend(framealpha=1, frameon=True, loc='upper right')

# %%
acc = abs(prediccion_test-valor_real_test)
porc_error = (acc / abs(valor_real_test)) * 100
mostrar = valor_real_test, prediccion_test, acc, porc_error
Tabla_arr = np.array(mostrar)
Tabla = np.transpose(Tabla_arr)
Tabla=Tabla.reshape(len(acc), -1)
Tabla_df = pd.DataFrame(Tabla, columns=['Datos predichos','Datos reales','Error','Error porcentual'])
Tabla_df
# Out:
#        Datos predichos  Datos reales     Error  Error porcentual
# 0               -19.34    -20.051563  0.711563          3.679231
# 1               -18.89    -19.698799  0.808799          4.281626
# 2               -19.34    -19.297174  0.042826          0.221435
# 3               -19.34    -19.955259  0.615259          3.181279
# 4               -19.19    -19.748125  0.558125          2.908416
# ...                ...           ...       ...               ...
# 41983           -14.46    -15.944655  1.484655         10.267327
# 41984           -14.02    -15.777130  1.757130         12.533025
# 41985           -13.73    -15.422799  1.692799         12.329200
# 41986           -13.43    -15.334984  1.904984         14.184541
# 41987           -13.43    -15.230879  1.800879         13.409373
#
# [41988 rows x 4 columns]

# %%
import seaborn as sns

# %%
aprendido_red=aprendido_train[:,0]
rial=reales_train[:,0]
testing=valor_real_test[:,0]
prediccion=prediccion_test[:,0]

# %%
sns.kdeplot(aprendido_red, cumulative=True)
sns.kdeplot(rial, cumulative=True)

# %%
err_apre=aprendido_train-reales_train
err_2=err_apre[:,0]
sns.kdeplot(err_2, cumulative=True)

# %%
sns.kdeplot(testing, cumulative=True)
sns.kdeplot(prediccion, cumulative=True)

# %%
err=prediccion_test-valor_real_test
err_1=err[:,0]
sns.kdeplot(err_1, cumulative=True)

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(POT2)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(aprendido_train)+look_back, :] = aprendido_train
# shift test predictions for plotting
testPredictPlot = np.empty_like(POT2)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(aprendido_train)+(look_back*2)+1:len(POT2)-1, :] = prediccion_test
# plot baseline and predictions
plt.figure(figsize=[12,12])
plt.plot((POT))
plt.plot(trainPredictPlot, color="red", )
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.plot(testPredictPlot, color="green")
plt.title("Predicciones de lo aprendido en rojo y verde en prueba", fontsize = 20)
plt.grid()
plt.show()

# %%
adqw=trainPredictPlot+testPredictPlot

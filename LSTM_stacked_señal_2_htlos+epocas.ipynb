# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import time
#A continuación se importan laas librerias necesarias para el entrenamiento de la red 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.layers import Activation
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from keras.layers import ConvLSTM2D
from keras.layers import Flatten
from keras.optimizers import SGD, Adam
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.

# %%
dataframe = pd.read_csv('/content/drive/My Drive/LSTM /Mediciones en csv/HTLOS CSV/potencia 2000-01-03 21_3A16_3A52 Antenna Horn Time 300[s] SwitchingBy 0 Horn 0 Omni 0 ING-AU_034.csv', header=None )
#llevar al dataframe a un arreglo de valores
dataset = dataframe.values
#dataset solo para la funcion senoidal
POT = dataset[0:len(dataset),1]
#POT = dataset
print(POT.shape)
plt.figure(figsize=[12,10])
plt.grid()
plt.plot(POT)
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.title("Datos reales", fontsize = 20)
# Out:
# (210619,)
# Text(0.5, 1.0, 'Datos reales')

# %% [markdown]
# # Nueva sección

# %%
#llevo la funcion a un arreglo de [lARGO DEL ARREGLO ,1] PARA ESCALAR LOS DATOS y que la red aprenda de mejor forma
POT2=POT.reshape(len(POT),1)
print(POT2.shape)
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
POT2 = scaler.fit_transform(POT2)
# Out:
# (210619, 1)

# %%
# divido la funcion y1 en arreglos para entrenar y probar la red
train_size = int(len(POT2) * 0.8)
test_size = len(POT2) - train_size
train, test = POT2[0:train_size,:], POT2[train_size:len(POT2),:]
print(len(train), len(test))
print(train.shape)
print(test.shape)
# Out:
# 168495 42124
# (168495, 1)
# (42124, 1)

# %%
# convertir un arreglo de valores en una matrix
def create_dataset(POT2, look_back=1):
    dataX, dataY = [], []
    for i in range(len(POT2)-look_back-1):
        a = POT2[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(POT2[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
# reshape dentro X=t and Y=t+1
look_back = 128
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
print(trainX.shape)
print(testX.shape)
print(trainY.shape)
print(testY.shape)
#print(trainX[0])
#print(trainY[0])
#print(trainX[1])
#print(trainY[1])
#print(trainX[2])
#print(trainY[3])
# Out:
# (168366, 128)
# (41995, 128)
# (168366,)
# (41995,)

# %%
# reshape a la entrada [samples, time steps, features] que es necesario para la red lstm
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
print(trainX.shape)
print(testX.shape)
# Out:
# (168366, 1, 128)
# (41995, 1, 128)

# %%
# create and fit the LSTM network
model = Sequential()

model.add(LSTM(256, activation = 'relu',return_sequences=True,input_shape=( 1, look_back)))
model.add(LSTM(128,return_sequences=True))
model.add(LSTM(64))
model.add(Dropout(0.2))
model.add(Dense(64))
model.add(Dense(32))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam',metrics=['mape','mse','mae'])
model.summary()
keras.utils.plot_model(model, 'my_first_model.png')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 1, 256)            394240
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1, 128)            197120
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 647,041
# Trainable params: 647,041
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
filepath="Checkpoint_mejores_pesos_señal_htlos_S2_lstm_stacked.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_mean_absolute_percentage_error', verbose=1, save_best_only=True, mode='min')
# simple early stopping
es = EarlyStopping(monitor='val_mean_absolute_percentage_error', mode='min', verbose=1, patience=5)

# %%
batch_size= 32 
epochs= 30
start = time.time()
History_htlos2_lstm_stacked = model.fit(trainX, trainY,batch_size=batch_size, epochs= epochs, callbacks=[es, checkpoint] , validation_split=0.1)
print("> Compilation Time : ", time.time() - start)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 151529 samples, validate on 16837 samples
# Epoch 1/30
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 151529/151529 [==============================] - 72s 476us/step - loss: 0.0018 - mean_absolute_percentage_error: 4171.0218 - mean_squared_error: 0.0018 - mean_absolute_error: 0.0232 - val_loss: 2.1033e-04 - val_mean_absolute_percentage_error: 1.5973 - val_mean_squared_error: 2.1033e-04 - val_mean_absolute_error: 0.0120
#
# Epoch 00001: val_mean_absolute_percentage_error improved from inf to 1.59734, saving model to Checkpoint_mejores_pesos_señal_htlos_S2_lstm_stacked.hdf5
# Epoch 2/30
# 151529/151529 [==============================] - 62s 406us/step - loss: 5.5191e-04 - mean_absolute_percentage_error: 3731.9999 - mean_squared_error: 5.5191e-04 - mean_absolute_error: 0.0155 - val_loss: 2.1635e-04 - val_mean_absolute_percentage_error: 1.6936 - val_mean_squared_error: 2.1635e-04 - val_mean_absolute_error: 0.0122
#
# Epoch 00002: val_mean_absolute_percentage_error did not improve from 1.59734
# Epoch 3/30
# 151529/151529 [==============================] - 61s 403us/step - loss: 4.7803e-04 - mean_absolute_percentage_error: 2956.7159 - mean_squared_error: 4.7803e-04 - mean_absolute_error: 0.0144 - val_loss: 3.2320e-04 - val_mean_absolute_percentage_error: 2.1454 - val_mean_squared_error: 3.2320e-04 - val_mean_absolute_error: 0.0163
#
# Epoch 00003: val_mean_absolute_percentage_error did not improve from 1.59734
# Epoch 4/30
# 151529/151529 [==============================] - 61s 402us/step - loss: 4.3552e-04 - mean_absolute_percentage_error: 4438.4603 - mean_squared_error: 4.3552e-04 - mean_absolute_error: 0.0135 - val_loss: 3.5176e-04 - val_mean_absolute_percentage_error: 2.0636 - val_mean_squared_error: 3.5176e-04 - val_mean_absolute_error: 0.0142
#
# Epoch 00004: val_mean_absolute_percentage_error did not improve from 1.59734
# Epoch 5/30
# 151529/151529 [==============================] - 61s 403us/step - loss: 4.2363e-04 - mean_absolute_percentage_error: 3339.0466 - mean_squared_error: 4.2363e-04 - mean_absolute_error: 0.0133 - val_loss: 3.9059e-04 - val_mean_absolute_percentage_error: 2.2034 - val_mean_squared_error: 3.9059e-04 - val_mean_absolute_error: 0.0176
#
# Epoch 00005: val_mean_absolute_percentage_error did not improve from 1.59734
# Epoch 6/30
# 151529/151529 [==============================] - 61s 402us/step - loss: 4.0236e-04 - mean_absolute_percentage_error: 3600.6080 - mean_squared_error: 4.0236e-04 - mean_absolute_error: 0.0129 - val_loss: 1.5376e-04 - val_mean_absolute_percentage_error: 1.3818 - val_mean_squared_error: 1.5376e-04 - val_mean_absolute_error: 0.0105
#
# Epoch 00006: val_mean_absolute_percentage_error improved from 1.59734 to 1.38177, saving model to Checkpoint_mejores_pesos_señal_htlos_S2_lstm_stacked.hdf5
# Epoch 7/30
# 151529/151529 [==============================] - 61s 404us/step - loss: 3.8697e-04 - mean_absolute_percentage_error: 2888.3374 - mean_squared_error: 3.8697e-04 - mean_absolute_error: 0.0126 - val_loss: 2.4216e-04 - val_mean_absolute_percentage_error: 1.8329 - val_mean_squared_error: 2.4216e-04 - val_mean_absolute_error: 0.0134
#
# Epoch 00007: val_mean_absolute_percentage_error did not improve from 1.38177
# Epoch 8/30
# 151529/151529 [==============================] - 61s 401us/step - loss: 3.7927e-04 - mean_absolute_percentage_error: 3952.9335 - mean_squared_error: 3.7927e-04 - mean_absolute_error: 0.0125 - val_loss: 1.0766e-04 - val_mean_absolute_percentage_error: 1.0819 - val_mean_squared_error: 1.0766e-04 - val_mean_absolute_error: 0.0080
#
# Epoch 00008: val_mean_absolute_percentage_error improved from 1.38177 to 1.08194, saving model to Checkpoint_mejores_pesos_señal_htlos_S2_lstm_stacked.hdf5
# Epoch 9/30
# 151529/151529 [==============================] - 61s 402us/step - loss: 3.6582e-04 - mean_absolute_percentage_error: 3565.6178 - mean_squared_error: 3.6582e-04 - mean_absolute_error: 0.0122 - val_loss: 1.5966e-04 - val_mean_absolute_percentage_error: 1.4500 - val_mean_squared_error: 1.5966e-04 - val_mean_absolute_error: 0.0108
#
# Epoch 00009: val_mean_absolute_percentage_error did not improve from 1.08194
# Epoch 10/30
# 151529/151529 [==============================] - 61s 401us/step - loss: 3.6210e-04 - mean_absolute_percentage_error: 2921.8123 - mean_squared_error: 3.6210e-04 - mean_absolute_error: 0.0121 - val_loss: 8.4484e-05 - val_mean_absolute_percentage_error: 0.8852 - val_mean_squared_error: 8.4484e-05 - val_mean_absolute_error: 0.0062
#
# Epoch 00010: val_mean_absolute_percentage_error improved from 1.08194 to 0.88516, saving model to Checkpoint_mejores_pesos_señal_htlos_S2_lstm_stacked.hdf5
# Epoch 11/30
# 151529/151529 [==============================] - 61s 403us/step - loss: 3.5347e-04 - mean_absolute_percentage_error: 3700.4096 - mean_squared_error: 3.5347e-04 - mean_absolute_error: 0.0119 - val_loss: 9.7874e-05 - val_mean_absolute_percentage_error: 0.9072 - val_mean_squared_error: 9.7874e-05 - val_mean_absolute_error: 0.0060
#
# Epoch 00011: val_mean_absolute_percentage_error did not improve from 0.88516
# Epoch 12/30
# 151529/151529 [==============================] - 61s 405us/step - loss: 3.5102e-04 - mean_absolute_percentage_error: 3484.5014 - mean_squared_error: 3.5102e-04 - mean_absolute_error: 0.0119 - val_loss: 2.5532e-04 - val_mean_absolute_percentage_error: 1.8604 - val_mean_squared_error: 2.5532e-04 - val_mean_absolute_error: 0.0131
#
# Epoch 00012: val_mean_absolute_percentage_error did not improve from 0.88516
# Epoch 13/30
# 151529/151529 [==============================] - 61s 402us/step - loss: 3.4458e-04 - mean_absolute_percentage_error: 3305.6414 - mean_squared_error: 3.4458e-04 - mean_absolute_error: 0.0118 - val_loss: 1.6136e-04 - val_mean_absolute_percentage_error: 1.4163 - val_mean_squared_error: 1.6136e-04 - val_mean_absolute_error: 0.0100
#
# Epoch 00013: val_mean_absolute_percentage_error did not improve from 0.88516
# Epoch 14/30
# 151529/151529 [==============================] - 61s 403us/step - loss: 3.3913e-04 - mean_absolute_percentage_error: 3488.5588 - mean_squared_error: 3.3913e-04 - mean_absolute_error: 0.0116 - val_loss: 7.8941e-05 - val_mean_absolute_percentage_error: 0.8386 - val_mean_squared_error: 7.8941e-05 - val_mean_absolute_error: 0.0059
#
# Epoch 00014: val_mean_absolute_percentage_error improved from 0.88516 to 0.83863, saving model to Checkpoint_mejores_pesos_señal_htlos_S2_lstm_stacked.hdf5
# Epoch 15/30
# 151529/151529 [==============================] - 61s 400us/step - loss: 3.3219e-04 - mean_absolute_percentage_error: 3225.2598 - mean_squared_error: 3.3219e-04 - mean_absolute_error: 0.0115 - val_loss: 1.1748e-04 - val_mean_absolute_percentage_error: 1.1169 - val_mean_squared_error: 1.1748e-04 - val_mean_absolute_error: 0.0079
#
# Epoch 00015: val_mean_absolute_percentage_error did not improve from 0.83863
# Epoch 16/30
# 151529/151529 [==============================] - 61s 400us/step - loss: 3.3393e-04 - mean_absolute_percentage_error: 3211.7030 - mean_squared_error: 3.3393e-04 - mean_absolute_error: 0.0114 - val_loss: 1.4702e-04 - val_mean_absolute_percentage_error: 1.3751 - val_mean_squared_error: 1.4702e-04 - val_mean_absolute_error: 0.0103
#
# Epoch 00016: val_mean_absolute_percentage_error did not improve from 0.83863
# Epoch 17/30
# 151529/151529 [==============================] - 61s 403us/step - loss: 3.2993e-04 - mean_absolute_percentage_error: 3561.9142 - mean_squared_error: 3.2993e-04 - mean_absolute_error: 0.0115 - val_loss: 3.2020e-04 - val_mean_absolute_percentage_error: 2.0666 - val_mean_squared_error: 3.2020e-04 - val_mean_absolute_error: 0.0163
#
# Epoch 00017: val_mean_absolute_percentage_error did not improve from 0.83863
# Epoch 18/30
# 151529/151529 [==============================] - 61s 400us/step - loss: 3.2481e-04 - mean_absolute_percentage_error: 3209.4808 - mean_squared_error: 3.2481e-04 - mean_absolute_error: 0.0113 - val_loss: 1.0135e-04 - val_mean_absolute_percentage_error: 1.0676 - val_mean_squared_error: 1.0135e-04 - val_mean_absolute_error: 0.0078
#
# Epoch 00018: val_mean_absolute_percentage_error did not improve from 0.83863
# Epoch 19/30
# 151529/151529 [==============================] - 61s 401us/step - loss: 3.2478e-04 - mean_absolute_percentage_error: 2760.3802 - mean_squared_error: 3.2478e-04 - mean_absolute_error: 0.0114 - val_loss: 8.1094e-05 - val_mean_absolute_percentage_error: 0.8337 - val_mean_squared_error: 8.1094e-05 - val_mean_absolute_error: 0.0057
#
# Epoch 00019: val_mean_absolute_percentage_error improved from 0.83863 to 0.83374, saving model to Checkpoint_mejores_pesos_señal_htlos_S2_lstm_stacked.hdf5
# Epoch 20/30
# 151529/151529 [==============================] - 61s 400us/step - loss: 3.2267e-04 - mean_absolute_percentage_error: 2968.0398 - mean_squared_error: 3.2267e-04 - mean_absolute_error: 0.0113 - val_loss: 1.2265e-04 - val_mean_absolute_percentage_error: 1.1855 - val_mean_squared_error: 1.2265e-04 - val_mean_absolute_error: 0.0085
#
# Epoch 00020: val_mean_absolute_percentage_error did not improve from 0.83374
# Epoch 21/30
# 151529/151529 [==============================] - 61s 400us/step - loss: 3.1526e-04 - mean_absolute_percentage_error: 3311.2886 - mean_squared_error: 3.1526e-04 - mean_absolute_error: 0.0111 - val_loss: 2.1790e-04 - val_mean_absolute_percentage_error: 1.5081 - val_mean_squared_error: 2.1790e-04 - val_mean_absolute_error: 0.0102
#
# Epoch 00021: val_mean_absolute_percentage_error did not improve from 0.83374
# Epoch 22/30
# 151529/151529 [==============================] - 61s 403us/step - loss: 3.1920e-04 - mean_absolute_percentage_error: 4051.3744 - mean_squared_error: 3.1920e-04 - mean_absolute_error: 0.0111 - val_loss: 7.7427e-05 - val_mean_absolute_percentage_error: 0.8153 - val_mean_squared_error: 7.7427e-05 - val_mean_absolute_error: 0.0056
#
# Epoch 00022: val_mean_absolute_percentage_error improved from 0.83374 to 0.81533, saving model to Checkpoint_mejores_pesos_señal_htlos_S2_lstm_stacked.hdf5
# Epoch 23/30
# 151529/151529 [==============================] - 61s 401us/step - loss: 3.1400e-04 - mean_absolute_percentage_error: 3189.2219 - mean_squared_error: 3.1400e-04 - mean_absolute_error: 0.0111 - val_loss: 1.1153e-04 - val_mean_absolute_percentage_error: 1.1312 - val_mean_squared_error: 1.1153e-04 - val_mean_absolute_error: 0.0082
#
# Epoch 00023: val_mean_absolute_percentage_error did not improve from 0.81533
# Epoch 24/30
# 151529/151529 [==============================] - 61s 400us/step - loss: 3.1455e-04 - mean_absolute_percentage_error: 3268.9007 - mean_squared_error: 3.1455e-04 - mean_absolute_error: 0.0111 - val_loss: 1.0647e-04 - val_mean_absolute_percentage_error: 0.9697 - val_mean_squared_error: 1.0647e-04 - val_mean_absolute_error: 0.0064
#
# Epoch 00024: val_mean_absolute_percentage_error did not improve from 0.81533
# Epoch 25/30
# 151529/151529 [==============================] - 61s 401us/step - loss: 3.0879e-04 - mean_absolute_percentage_error: 3148.8954 - mean_squared_error: 3.0879e-04 - mean_absolute_error: 0.0109 - val_loss: 6.2522e-04 - val_mean_absolute_percentage_error: 3.1766 - val_mean_squared_error: 6.2522e-04 - val_mean_absolute_error: 0.0235
#
# Epoch 00025: val_mean_absolute_percentage_error did not improve from 0.81533
# Epoch 26/30
# 151529/151529 [==============================] - 61s 401us/step - loss: 3.0850e-04 - mean_absolute_percentage_error: 3161.8625 - mean_squared_error: 3.0850e-04 - mean_absolute_error: 0.0109 - val_loss: 9.8174e-05 - val_mean_absolute_percentage_error: 0.9967 - val_mean_squared_error: 9.8174e-05 - val_mean_absolute_error: 0.0069
#
# Epoch 00026: val_mean_absolute_percentage_error did not improve from 0.81533
# Epoch 27/30
# 151529/151529 [==============================] - 65s 431us/step - loss: 3.0866e-04 - mean_absolute_percentage_error: 2732.2233 - mean_squared_error: 3.0866e-04 - mean_absolute_error: 0.0109 - val_loss: 1.9806e-04 - val_mean_absolute_percentage_error: 1.6305 - val_mean_squared_error: 1.9806e-04 - val_mean_absolute_error: 0.0124
#
# Epoch 00027: val_mean_absolute_percentage_error did not improve from 0.81533
# Epoch 00027: early stopping
# > Compilation Time :  1662.8402087688446

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model_htlos_señal2_lstm_stacked.json", "w") as json_file:
    json_file.write(model_json)

# %%
import pickle

pickle_out = open("History_htlos2_lstm_stacked.pickle","wb")
pickle.dump(History_htlos2_lstm_stacked, pickle_out)
pickle_out.close()

# %%
import pickle 

pickle_in = open("History_htlos2_lstm_stacked.pickle","rb")
History_saved = pickle.load(pickle_in)

# %%
History = History_saved

# %%
# plot metrics
#plt.figure(figsize=[8,8])
plt.plot(History.history['mean_squared_error'], label='mse')
plt.plot(History.history['val_mean_squared_error'], label= 'validación_mse')
plt.xlabel("epocas",fontsize = 16)
plt.ylabel("loss",fontsize = 16)
plt.legend(framealpha=1, frameon=True)

# %%
plt.plot(History.history['mean_absolute_error'], label='mae')
plt.plot(History.history['val_mean_absolute_error'], label= 'validación_mae')
plt.xlabel("epocas",fontsize = 16)
plt.ylabel("loss",fontsize = 16)
plt.legend(framealpha=1, frameon=True)

# %%
#History.history['mean_absolute_percentage_error']

# %%
plt.plot(History.history['mean_absolute_percentage_error'], label= 'mape')
plt.plot(History.history['val_mean_absolute_percentage_error'], label= 'validación_mape')
plt.xlabel("epocas",fontsize = 16)
plt.ylabel("loss",fontsize = 16)
plt.legend(framealpha=1, frameon=True)

# %%
# predicciones de los valores de prueba
prediccion_test = model.predict(testX)
prediccion_test = scaler.inverse_transform(prediccion_test)
#actuals = test_y
valor_real_test = scaler.inverse_transform([testY])
valor_real_test= valor_real_test.reshape(len(prediccion_test),1)
#prediccion de los valores de entrenamiento
aprendido=model.predict(trainX)
aprendido_train=scaler.inverse_transform(aprendido)
reales_train=scaler.inverse_transform([trainY])
reales_train=scaler.inverse_transform([trainY])
reales_train=reales_train.reshape(len(aprendido),1)
###################################################
mse_aprendido=mean_squared_error(reales_train,aprendido_train)
mse_test=mean_squared_error(valor_real_test,prediccion_test)
print('Train Mean square Error:', mse_aprendido)
print('Test Mean square Error:', mse_test)
#######################################################
rmse_train=math.sqrt(mse_aprendido)
rmse_test=math.sqrt(mse_test)
print('Train Root Mean Squared Error:', rmse_train)
print('Test Root Mean Squared Error:', rmse_test)
# Out:
# Train Mean square Error: 0.7531850406914529
# Test Mean square Error: 1.052293593498335
# Train Root Mean Squared Error: 0.8678623397126142
# Test Root Mean Squared Error: 1.025813625128042

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
#mape train
mean_absolute_percentage_error(reales_train,aprendido_train)
# Out:
# 4.992847473192855

# %%
#mape test
mean_absolute_percentage_error(valor_real_test,prediccion_test)
# Out:
# 6.7126088024887105

# %%
def smape(y_true, y_pred):
    denominator = (np.abs(y_true) + np.abs(y_pred))
    diff = np.abs(y_true - y_pred) / denominator
    diff[denominator == 0] = 0.0
    return 200 * np.mean(diff)

# %%
smape(reales_train,aprendido_train)
# Out:
# 4.84169620694185

# %%
smape(valor_real_test,prediccion_test)
# Out:
# 6.445980901163033

# %%
# plot entrenamiento
plt.figure(figsize=[12,12])
plt.plot(reales_train, label='Datos reales')
plt.plot(aprendido_train, label= 'predicciones aprendido')
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.legend(framealpha=1, frameon=True, loc='upper right')

# %%
# plot test
plt.figure(figsize=[12,12])
plt.plot(valor_real_test, label='Datos reales')
plt.plot(prediccion_test , label= 'predicciones test')
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.legend(framealpha=1, frameon=True, loc='upper right')

# %%
# plot test
plt.figure(figsize=[12,12])
plt.plot(valor_real_test[17200:17500], label='Datos reales')
plt.plot(prediccion_test[17200:17500], label= 'predicciones test')
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.legend(framealpha=1, frameon=True, loc='upper right')

# %%
acc = abs(prediccion_test-valor_real_test)
porc_error = (acc / abs(valor_real_test)) * 100
mostrar = valor_real_test, prediccion_test, acc, porc_error
Tabla_arr = np.array(mostrar)
Tabla = np.transpose(Tabla_arr)
Tabla=Tabla.reshape(len(acc), -1)
Tabla_df = pd.DataFrame(Tabla, columns=['Datos predichos','Datos reales','Error','Error porcentual'])
Tabla_df
# Out:
#        Datos predichos  Datos reales     Error  Error porcentual
# 0               -15.94    -16.467367  0.527367          3.308452
# 1               -16.09    -16.662298  0.572298          3.556856
# 2               -16.24    -16.742826  0.502826          3.096222
# 3               -16.09    -16.848042  0.758042          4.711259
# 4               -15.94    -16.674368  0.734368          4.607076
# ...                ...           ...       ...               ...
# 41990           -13.87    -14.156114  0.286114          2.062824
# 41991           -14.02    -14.325718  0.305718          2.180584
# 41992           -13.87    -14.425241  0.555241          4.003183
# 41993           -14.02    -14.302144  0.282144          2.012440
# 41994           -14.32    -14.455214  0.135214          0.944229
#
# [41995 rows x 4 columns]

# %%
import seaborn as sns

# %%
aprendido_red=aprendido_train[:,0]
rial=reales_train[:,0]
testing=valor_real_test[:,0]
prediccion=prediccion_test[:,0]

# %%
sns.kdeplot(aprendido_red, cumulative=True)
sns.kdeplot(rial, cumulative=True)

# %%
err_apre=aprendido_train-reales_train
err_2=err_apre[:,0]
sns.kdeplot(err_2, cumulative=True)

# %%
sns.kdeplot(testing, cumulative=True)
sns.kdeplot(prediccion, cumulative=True)

# %%
err=prediccion_test-valor_real_test
err_1=err[:,0]
sns.kdeplot(err_1, cumulative=True)

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(POT2)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(aprendido_train)+look_back, :] = aprendido_train
# shift test predictions for plotting
testPredictPlot = np.empty_like(POT2)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(aprendido_train)+(look_back*2)+1:len(POT2)-1, :] = prediccion_test
# plot baseline and predictions
plt.figure(figsize=[12,12])
plt.plot((POT))
plt.plot(trainPredictPlot, color="red", )
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.plot(testPredictPlot, color="green")
plt.title("Predicciones de lo aprendido en rojo y verde en prueba", fontsize = 20)
plt.grid()
plt.show()

# %%
adqw=trainPredictPlot+testPredictPlot

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import time
#A continuación se importan laas librerias necesarias para el entrenamiento de la red 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.layers import Activation
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from keras.layers import ConvLSTM2D
from keras.layers import Flatten
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.

# %%
dataframe = pd.read_csv('/content/drive/My Drive/LSTM /Mediciones en csv/LTLOS CSV/potencia 2000-01-30 22_3A28_3A17 Antenna Horn Time 300[s] SwitchingBy 0 Horn 0 Omni 0 FIN_017.csv', header=None )
#llevar al dataframe a un arreglo de valores
dataset = dataframe.values
#dataset solo para la funcion senoidal
POT = dataset[0:len(dataset),1]
#POT = dataset
print(POT.shape)
plt.figure(figsize=[12,10])
plt.grid()
plt.plot(POT)
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.title("Datos reales", fontsize = 20)
# Out:
# (210909,)
# Text(0.5, 1.0, 'Datos reales')

# %% [markdown]
# # Nueva sección

# %%
#llevo la funcion a un arreglo de [lARGO DEL ARREGLO ,1] PARA ESCALAR LOS DATOS y que la red aprenda de mejor forma
POT2=POT.reshape(len(POT),1)
print(POT2.shape)
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
POT2 = scaler.fit_transform(POT2)
# Out:
# (210909, 1)

# %%
# divido la funcion y1 en arreglos para entrenar y probar la red
train_size = int(len(POT2) * 0.8)
test_size = len(POT2) - train_size
train, test = POT2[0:train_size,:], POT2[train_size:len(POT2),:]
print(len(train), len(test))
print(train.shape)
print(test.shape)
# Out:
# 168727 42182
# (168727, 1)
# (42182, 1)

# %%
# convertir un arreglo de valores en una matrix
def create_dataset(POT2, look_back=1):
    dataX, dataY = [], []
    for i in range(len(POT2)-look_back-1):
        a = POT2[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(POT2[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
# reshape dentro X=t and Y=t+1
look_back = 128
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
print(trainX.shape)
print(testX.shape)
print(trainY.shape)
print(testY.shape)
#print(trainX[0])
#print(trainY[0])
#print(trainX[1])
#print(trainY[1])
#print(trainX[2])
#print(trainY[3])
# Out:
# (168598, 128)
# (42053, 128)
# (168598,)
# (42053,)

# %%
#n_timesteps, n_features, n_outputs = trainX.shape[1], trainX.shape[2], trainy.shape[1]
# reshape into subsequences (samples, time steps, rows, cols, channels)
n_steps, n_length, n_features = 4, 32, 1
trainX = trainX.reshape((trainX.shape[0], n_steps, 1, n_length, n_features))
testX = testX.reshape((testX.shape[0], n_steps, 1, n_length, n_features))

# %%
model = Sequential()
model.add(ConvLSTM2D(filters=128, kernel_size=(1,3), return_sequences = True ,activation='relu', input_shape=(n_steps, 1, n_length, n_features)))
#model.add(ConvLSTM2D(filters=32, kernel_size=(1,3), input_shape=(n_steps, 1, n_length, n_features)))
model.add(Dropout(0.3))
model.add(ConvLSTM2D(filters=128, kernel_size=(1,3), activation='relu', input_shape=(n_steps, 1, n_length, n_features)))
#model.add(LSTM(input_shape = (None, None, 32, 1), output_dim= 128, return_sequences = True))
model.add(Dropout(0.3))
#model.add(LSTM(128))
#model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse', 'mae', 'mape'])
model.summary()
keras.utils.plot_model(model, 'my_first_model.png')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_lst_m2d_3 (ConvLSTM2D)  (None, 4, 1, 30, 128)     198656
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 1, 30, 128)     0
# _________________________________________________________________
# conv_lst_m2d_4 (ConvLSTM2D)  (None, 1, 28, 128)        393728
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1, 28, 128)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 3584)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 3585
# =================================================================
# Total params: 595,969
# Trainable params: 595,969
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
filepath="Checkpoint_mejores_pesos_señal_ltlos_S1.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_mean_absolute_percentage_error', verbose=1, save_best_only=True, mode='min')
# simple early stopping
es = EarlyStopping(monitor='val_mean_absolute_percentage_error', mode='min', verbose=1, patience=5)

# %%
batch_size= 64 
epochs= 30
start = time.time()
History_ltlos1 = model.fit(trainX, trainY,batch_size=batch_size, epochs= epochs, callbacks=[es, checkpoint] , validation_split=0.1)
print("> Compilation Time : ", time.time() - start)
# Out:
# Train on 151738 samples, validate on 16860 samples
# Epoch 1/30
# 151738/151738 [==============================] - 116s 762us/step - loss: 0.0033 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0287 - mean_absolute_percentage_error: 4152.5415 - val_loss: 1.7797e-04 - val_mean_squared_error: 1.7797e-04 - val_mean_absolute_error: 0.0045 - val_mean_absolute_percentage_error: 0.5696
#
# Epoch 00001: val_mean_absolute_percentage_error improved from inf to 0.56965, saving model to Checkpoint_mejores_pesos_señal_ltlos_S1.hdf5
# Epoch 2/30
# 151738/151738 [==============================] - 108s 709us/step - loss: 6.1699e-04 - mean_squared_error: 6.1699e-04 - mean_absolute_error: 0.0176 - mean_absolute_percentage_error: 3458.1816 - val_loss: 2.2723e-04 - val_mean_squared_error: 2.2723e-04 - val_mean_absolute_error: 0.0123 - val_mean_absolute_percentage_error: 1.3761
#
# Epoch 00002: val_mean_absolute_percentage_error did not improve from 0.56965
# Epoch 3/30
# 151738/151738 [==============================] - 107s 707us/step - loss: 4.7080e-04 - mean_squared_error: 4.7080e-04 - mean_absolute_error: 0.0155 - mean_absolute_percentage_error: 3211.5072 - val_loss: 6.4102e-05 - val_mean_squared_error: 6.4102e-05 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 0.4281
#
# Epoch 00003: val_mean_absolute_percentage_error improved from 0.56965 to 0.42808, saving model to Checkpoint_mejores_pesos_señal_ltlos_S1.hdf5
# Epoch 4/30
# 151738/151738 [==============================] - 107s 704us/step - loss: 3.9172e-04 - mean_squared_error: 3.9172e-04 - mean_absolute_error: 0.0140 - mean_absolute_percentage_error: 3115.3861 - val_loss: 9.0715e-05 - val_mean_squared_error: 9.0715e-05 - val_mean_absolute_error: 0.0054 - val_mean_absolute_percentage_error: 0.6293
#
# Epoch 00004: val_mean_absolute_percentage_error did not improve from 0.42808
# Epoch 5/30
# 151738/151738 [==============================] - 107s 702us/step - loss: 3.4389e-04 - mean_squared_error: 3.4389e-04 - mean_absolute_error: 0.0130 - mean_absolute_percentage_error: 2270.5964 - val_loss: 9.4678e-05 - val_mean_squared_error: 9.4678e-05 - val_mean_absolute_error: 0.0069 - val_mean_absolute_percentage_error: 0.7756
#
# Epoch 00005: val_mean_absolute_percentage_error did not improve from 0.42808
# Epoch 6/30
# 151738/151738 [==============================] - 106s 701us/step - loss: 2.9217e-04 - mean_squared_error: 2.9217e-04 - mean_absolute_error: 0.0118 - mean_absolute_percentage_error: 2621.0433 - val_loss: 7.3555e-05 - val_mean_squared_error: 7.3555e-05 - val_mean_absolute_error: 0.0063 - val_mean_absolute_percentage_error: 0.7147
#
# Epoch 00006: val_mean_absolute_percentage_error did not improve from 0.42808
# Epoch 7/30
# 151738/151738 [==============================] - 106s 701us/step - loss: 2.5481e-04 - mean_squared_error: 2.5481e-04 - mean_absolute_error: 0.0108 - mean_absolute_percentage_error: 2740.2702 - val_loss: 4.6325e-05 - val_mean_squared_error: 4.6325e-05 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 0.4174
#
# Epoch 00007: val_mean_absolute_percentage_error improved from 0.42808 to 0.41738, saving model to Checkpoint_mejores_pesos_señal_ltlos_S1.hdf5
# Epoch 8/30
# 151738/151738 [==============================] - 106s 700us/step - loss: 2.2107e-04 - mean_squared_error: 2.2107e-04 - mean_absolute_error: 0.0100 - mean_absolute_percentage_error: 2700.8384 - val_loss: 4.6149e-05 - val_mean_squared_error: 4.6149e-05 - val_mean_absolute_error: 0.0042 - val_mean_absolute_percentage_error: 0.4834
#
# Epoch 00008: val_mean_absolute_percentage_error did not improve from 0.41738
# Epoch 9/30
# 151738/151738 [==============================] - 106s 699us/step - loss: 1.9306e-04 - mean_squared_error: 1.9306e-04 - mean_absolute_error: 0.0092 - mean_absolute_percentage_error: 2386.9971 - val_loss: 4.1589e-05 - val_mean_squared_error: 4.1589e-05 - val_mean_absolute_error: 0.0039 - val_mean_absolute_percentage_error: 0.4457
#
# Epoch 00009: val_mean_absolute_percentage_error did not improve from 0.41738
# Epoch 10/30
# 151738/151738 [==============================] - 106s 701us/step - loss: 1.7269e-04 - mean_squared_error: 1.7269e-04 - mean_absolute_error: 0.0086 - mean_absolute_percentage_error: 1351.4660 - val_loss: 3.6019e-05 - val_mean_squared_error: 3.6019e-05 - val_mean_absolute_error: 0.0037 - val_mean_absolute_percentage_error: 0.4142
#
# Epoch 00010: val_mean_absolute_percentage_error improved from 0.41738 to 0.41419, saving model to Checkpoint_mejores_pesos_señal_ltlos_S1.hdf5
# Epoch 11/30
# 151738/151738 [==============================] - 106s 699us/step - loss: 1.5321e-04 - mean_squared_error: 1.5321e-04 - mean_absolute_error: 0.0080 - mean_absolute_percentage_error: 2146.4031 - val_loss: 2.4343e-05 - val_mean_squared_error: 2.4343e-05 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 0.2961
#
# Epoch 00011: val_mean_absolute_percentage_error improved from 0.41419 to 0.29614, saving model to Checkpoint_mejores_pesos_señal_ltlos_S1.hdf5
# Epoch 12/30
# 151738/151738 [==============================] - 106s 699us/step - loss: 1.4385e-04 - mean_squared_error: 1.4385e-04 - mean_absolute_error: 0.0075 - mean_absolute_percentage_error: 2762.0605 - val_loss: 2.6123e-05 - val_mean_squared_error: 2.6123e-05 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 0.3034
#
# Epoch 00012: val_mean_absolute_percentage_error did not improve from 0.29614
# Epoch 13/30
# 151738/151738 [==============================] - 106s 699us/step - loss: 1.3034e-04 - mean_squared_error: 1.3034e-04 - mean_absolute_error: 0.0070 - mean_absolute_percentage_error: 2709.9778 - val_loss: 3.0287e-05 - val_mean_squared_error: 3.0287e-05 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 0.3371
#
# Epoch 00013: val_mean_absolute_percentage_error did not improve from 0.29614
# Epoch 14/30
# 151738/151738 [==============================] - 106s 698us/step - loss: 1.2579e-04 - mean_squared_error: 1.2579e-04 - mean_absolute_error: 0.0068 - mean_absolute_percentage_error: 1608.1431 - val_loss: 2.5412e-05 - val_mean_squared_error: 2.5412e-05 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 0.2935
#
# Epoch 00014: val_mean_absolute_percentage_error improved from 0.29614 to 0.29347, saving model to Checkpoint_mejores_pesos_señal_ltlos_S1.hdf5
# Epoch 15/30
# 151738/151738 [==============================] - 106s 699us/step - loss: 1.1671e-04 - mean_squared_error: 1.1671e-04 - mean_absolute_error: 0.0065 - mean_absolute_percentage_error: 2425.7649 - val_loss: 2.5622e-05 - val_mean_squared_error: 2.5622e-05 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 0.3761
#
# Epoch 00015: val_mean_absolute_percentage_error did not improve from 0.29347
# Epoch 16/30
# 151738/151738 [==============================] - 106s 698us/step - loss: 1.0998e-04 - mean_squared_error: 1.0998e-04 - mean_absolute_error: 0.0064 - mean_absolute_percentage_error: 185.3977 - val_loss: 2.1196e-05 - val_mean_squared_error: 2.1196e-05 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 0.2821
#
# Epoch 00016: val_mean_absolute_percentage_error improved from 0.29347 to 0.28213, saving model to Checkpoint_mejores_pesos_señal_ltlos_S1.hdf5
# Epoch 17/30
# 151738/151738 [==============================] - 105s 694us/step - loss: 1.0570e-04 - mean_squared_error: 1.0570e-04 - mean_absolute_error: 0.0062 - mean_absolute_percentage_error: 817.5615 - val_loss: 3.2565e-05 - val_mean_squared_error: 3.2565e-05 - val_mean_absolute_error: 0.0045 - val_mean_absolute_percentage_error: 0.4994
#
# Epoch 00017: val_mean_absolute_percentage_error did not improve from 0.28213
# Epoch 18/30
# 151738/151738 [==============================] - 107s 705us/step - loss: 1.0342e-04 - mean_squared_error: 1.0342e-04 - mean_absolute_error: 0.0060 - mean_absolute_percentage_error: 1856.7798 - val_loss: 4.5251e-05 - val_mean_squared_error: 4.5251e-05 - val_mean_absolute_error: 0.0056 - val_mean_absolute_percentage_error: 0.6212
#
# Epoch 00018: val_mean_absolute_percentage_error did not improve from 0.28213
# Epoch 19/30
# 151738/151738 [==============================] - 106s 698us/step - loss: 1.0262e-04 - mean_squared_error: 1.0262e-04 - mean_absolute_error: 0.0059 - mean_absolute_percentage_error: 234.7572 - val_loss: 2.3044e-05 - val_mean_squared_error: 2.3044e-05 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 0.3228
#
# Epoch 00019: val_mean_absolute_percentage_error did not improve from 0.28213
# Epoch 20/30
# 151738/151738 [==============================] - 106s 696us/step - loss: 9.5391e-05 - mean_squared_error: 9.5391e-05 - mean_absolute_error: 0.0057 - mean_absolute_percentage_error: 2043.8083 - val_loss: 1.5398e-05 - val_mean_squared_error: 1.5398e-05 - val_mean_absolute_error: 0.0022 - val_mean_absolute_percentage_error: 0.2487
#
# Epoch 00020: val_mean_absolute_percentage_error improved from 0.28213 to 0.24868, saving model to Checkpoint_mejores_pesos_señal_ltlos_S1.hdf5
# Epoch 21/30
# 151738/151738 [==============================] - 106s 698us/step - loss: 9.7262e-05 - mean_squared_error: 9.7262e-05 - mean_absolute_error: 0.0057 - mean_absolute_percentage_error: 2423.8657 - val_loss: 1.6874e-05 - val_mean_squared_error: 1.6874e-05 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 0.2649
#
# Epoch 00021: val_mean_absolute_percentage_error did not improve from 0.24868
# Epoch 22/30
# 151738/151738 [==============================] - 106s 698us/step - loss: 9.3527e-05 - mean_squared_error: 9.3527e-05 - mean_absolute_error: 0.0056 - mean_absolute_percentage_error: 965.2167 - val_loss: 4.1432e-05 - val_mean_squared_error: 4.1432e-05 - val_mean_absolute_error: 0.0052 - val_mean_absolute_percentage_error: 0.5798
#
# Epoch 00022: val_mean_absolute_percentage_error did not improve from 0.24868
# Epoch 23/30
# 151738/151738 [==============================] - 106s 697us/step - loss: 8.9249e-05 - mean_squared_error: 8.9249e-05 - mean_absolute_error: 0.0055 - mean_absolute_percentage_error: 859.0660 - val_loss: 4.2176e-05 - val_mean_squared_error: 4.2176e-05 - val_mean_absolute_error: 0.0052 - val_mean_absolute_percentage_error: 0.5794
#
# Epoch 00023: val_mean_absolute_percentage_error did not improve from 0.24868
# Epoch 24/30
# 151738/151738 [==============================] - 106s 700us/step - loss: 9.1357e-05 - mean_squared_error: 9.1357e-05 - mean_absolute_error: 0.0055 - mean_absolute_percentage_error: 2566.9971 - val_loss: 3.2684e-05 - val_mean_squared_error: 3.2684e-05 - val_mean_absolute_error: 0.0045 - val_mean_absolute_percentage_error: 0.5050
#
# Epoch 00024: val_mean_absolute_percentage_error did not improve from 0.24868
# Epoch 25/30
# 151738/151738 [==============================] - 106s 701us/step - loss: 8.6695e-05 - mean_squared_error: 8.6695e-05 - mean_absolute_error: 0.0053 - mean_absolute_percentage_error: 1238.5051 - val_loss: 2.9424e-05 - val_mean_squared_error: 2.9424e-05 - val_mean_absolute_error: 0.0041 - val_mean_absolute_percentage_error: 0.4603
#
# Epoch 00025: val_mean_absolute_percentage_error did not improve from 0.24868
# Epoch 00025: early stopping
# > Compilation Time :  2667.767097234726

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model_ltlos_señal1.json", "w") as json_file:
    json_file.write(model_json)

# %%
import pickle

pickle_out = open("History_ltlos1.pickle","wb")
pickle.dump(History_ltlos1, pickle_out)
pickle_out.close()

# %%
import pickle 

pickle_in = open("History_ltlos1.pickle","rb")
History_saved = pickle.load(pickle_in)

# %%
History = History_saved

# %%
# plot metrics
#plt.figure(figsize=[8,8])
plt.plot(History.history['mean_squared_error'], label='mse')
plt.plot(History.history['val_mean_squared_error'], label= 'validación_mse')
plt.xlabel("epocas",fontsize = 16)
plt.ylabel("loss",fontsize = 16)
plt.legend(framealpha=1, frameon=True)

# %%
plt.plot(History.history['mean_absolute_error'], label='mae')
plt.plot(History.history['val_mean_absolute_error'], label= 'validación_mae')
plt.xlabel("epocas",fontsize = 16)
plt.ylabel("loss",fontsize = 16)
plt.legend(framealpha=1, frameon=True)

# %%
#History.history['mean_absolute_percentage_error']

# %%
plt.plot(History.history['mean_absolute_percentage_error'], label= 'mape')
plt.plot(History.history['val_mean_absolute_percentage_error'], label= 'validación_mape')
plt.xlabel("epocas",fontsize = 16)
plt.ylabel("loss",fontsize = 16)
plt.legend(framealpha=1, frameon=True)

# %%
# predicciones de los valores de prueba
prediccion_test = model.predict(testX)
prediccion_test = scaler.inverse_transform(prediccion_test)
#actuals = test_y
valor_real_test = scaler.inverse_transform([testY])
valor_real_test= valor_real_test.reshape(len(prediccion_test),1)
#prediccion de los valores de entrenamiento
aprendido=model.predict(trainX)
aprendido_train=scaler.inverse_transform(aprendido)
reales_train=scaler.inverse_transform([trainY])
reales_train=scaler.inverse_transform([trainY])
reales_train=reales_train.reshape(len(aprendido),1)
###################################################
mse_aprendido=mean_squared_error(reales_train,aprendido_train)
mse_test=mean_squared_error(valor_real_test,prediccion_test)
print('Train Mean square Error:', mse_aprendido)
print('Test Mean square Error:', mse_test)
#######################################################
rmse_train=math.sqrt(mse_aprendido)
rmse_test=math.sqrt(mse_test)
print('Train Root Mean Squared Error:', rmse_train)
print('Test Root Mean Squared Error:', rmse_test)
# Out:
# Train Mean square Error: 0.11089051497338251
# Test Mean square Error: 0.13989266434105904
# Train Root Mean Squared Error: 0.33300227472703925
# Test Root Mean Squared Error: 0.3740222778673204

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
#mape train
mean_absolute_percentage_error(reales_train,aprendido_train)
# Out:
# 2.654055447989815

# %%
#mape test
mean_absolute_percentage_error(valor_real_test,prediccion_test)
# Out:
# 2.5698916288090583

# %%
def smape(y_true, y_pred):
    denominator = (np.abs(y_true) + np.abs(y_pred))
    diff = np.abs(y_true - y_pred) / denominator
    diff[denominator == 0] = 0.0
    return 200 * np.mean(diff)

# %%
smape(reales_train,aprendido_train)
# Out:
# 2.6960726823858105

# %%
smape(valor_real_test,prediccion_test)
# Out:
# 2.6053981616432154

# %%
# plot entrenamiento
plt.figure(figsize=[12,12])
plt.plot(reales_train, label='Datos reales')
plt.plot(aprendido_train, label= 'predicciones aprendido')
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.legend(framealpha=1, frameon=True, loc='upper right')

# %%
# plot test
plt.figure(figsize=[12,12])
plt.plot(valor_real_test, label='Datos reales')
plt.plot(prediccion_test , label= 'predicciones test')
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.legend(framealpha=1, frameon=True, loc='upper right')

# %%
# plot test
plt.figure(figsize=[12,12])
plt.plot(valor_real_test[12000:15000], label='Datos reales')
plt.plot(prediccion_test[12000:15000] , label= 'predicciones test')
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.legend(framealpha=1, frameon=True, loc='upper right')

# %%
acc = abs(prediccion_test-valor_real_test)
porc_error = (acc / abs(valor_real_test)) * 100
mostrar = valor_real_test, prediccion_test, acc, porc_error
Tabla_arr = np.array(mostrar)
Tabla = np.transpose(Tabla_arr)
Tabla=Tabla.reshape(len(acc), -1)
Tabla_df = pd.DataFrame(Tabla, columns=['Datos predichos','Datos reales','Error','Error porcentual'])
Tabla_df
# Out:
#        Datos predichos  Datos reales     Error  Error porcentual
# 0                -6.64     -6.615262  0.024738          0.372567
# 1                -6.64     -6.599537  0.040463          0.609377
# 2                -6.79     -6.591732  0.198268          2.920007
# 3                -6.79     -6.644584  0.145416          2.141624
# 4                -6.79     -6.663194  0.126806          1.867538
# ...                ...           ...       ...               ...
# 42048            -7.53     -7.359873  0.170127          2.259325
# 42049            -7.53     -7.358284  0.171716          2.280431
# 42050            -7.53     -7.355371  0.174629          2.319104
# 42051            -7.53     -7.353860  0.176140          2.339178
# 42052            -7.38     -7.362784  0.017216          0.233274
#
# [42053 rows x 4 columns]

# %%
import seaborn as sns

# %%
aprendido_red=aprendido_train[:,0]
rial=reales_train[:,0]
testing=valor_real_test[:,0]
prediccion=prediccion_test[:,0]

# %%
sns.kdeplot(aprendido_red, cumulative=True)
sns.kdeplot(rial, cumulative=True)

# %%
sns.kdeplot(testing, cumulative=True)
sns.kdeplot(prediccion, cumulative=True)

# %%
err=prediccion_test-valor_real_test
err_1=err[:,0]
sns.kdeplot(err_1, cumulative=True)

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(POT2)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(aprendido_train)+look_back, :] = aprendido_train
# shift test predictions for plotting
testPredictPlot = np.empty_like(POT2)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(aprendido_train)+(look_back*2)+1:len(POT2)-1, :] = prediccion_test
# plot baseline and predictions
plt.figure(figsize=[12,12])
plt.plot((POT))
plt.plot(trainPredictPlot, color="red", )
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.plot(testPredictPlot, color="green")
plt.title("Predicciones de lo aprendido en rojo y verde en prueba", fontsize = 20)
plt.grid()
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import time
#A continuación se importan laas librerias necesarias para el entrenamiento de la red 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.layers import Activation
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from keras.layers import ConvLSTM2D
from keras.layers import Flatten
from keras.optimizers import SGD, Adam
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.

# %%
dataframe = pd.read_csv('/content/drive/My Drive/LSTM /Mediciones en csv/LTLOS CSV/potencia 2000-01-30 22_3A35_3A55 Antenna Horn Time 300[s] SwitchingBy 0 Horn 0 Omni 0 FIN_018.csv', header=None )
#llevar al dataframe a un arreglo de valores
dataset = dataframe.values
#dataset solo para la funcion senoidal
POT = dataset[0:len(dataset),1]
#POT = dataset
print(POT.shape)
plt.figure(figsize=[12,10])
plt.grid()
plt.plot(POT)
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.title("Datos reales", fontsize = 20)
# Out:
# (210721,)
# Text(0.5, 1.0, 'Datos reales')

# %% [markdown]
# # Nueva sección

# %%
#llevo la funcion a un arreglo de [lARGO DEL ARREGLO ,1] PARA ESCALAR LOS DATOS y que la red aprenda de mejor forma
POT2=POT.reshape(len(POT),1)
print(POT2.shape)
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
POT2 = scaler.fit_transform(POT2)
# Out:
# (210721, 1)

# %%
# divido la funcion y1 en arreglos para entrenar y probar la red
train_size = int(len(POT2) * 0.8)
test_size = len(POT2) - train_size
train, test = POT2[0:train_size,:], POT2[train_size:len(POT2),:]
print(len(train), len(test))
print(train.shape)
print(test.shape)
# Out:
# 168576 42145
# (168576, 1)
# (42145, 1)

# %%
# convertir un arreglo de valores en una matrix
def create_dataset(POT2, look_back=1):
    dataX, dataY = [], []
    for i in range(len(POT2)-look_back-1):
        a = POT2[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(POT2[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
# reshape dentro X=t and Y=t+1
look_back = 128
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
print(trainX.shape)
print(testX.shape)
print(trainY.shape)
print(testY.shape)
#print(trainX[0])
#print(trainY[0])
#print(trainX[1])
#print(trainY[1])
#print(trainX[2])
#print(trainY[3])
# Out:
# (168447, 128)
# (42016, 128)
# (168447,)
# (42016,)

# %%
# reshape a la entrada [samples, time steps, features] que es necesario para la red lstm
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
print(trainX.shape)
print(testX.shape)
# Out:
# (168447, 1, 128)
# (42016, 1, 128)

# %%
# create and fit the LSTM network
model = Sequential()

model.add(LSTM(256, activation = 'relu',return_sequences=True,input_shape=( 1, look_back)))
model.add(LSTM(128,return_sequences=True))
model.add(LSTM(64))
model.add(Dropout(0.2))
model.add(Dense(64))
model.add(Dense(32))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam',metrics=['mape','mse','mae'])
model.summary()
keras.utils.plot_model(model, 'my_first_model.png')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 1, 256)            394240
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1, 128)            197120
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 647,041
# Trainable params: 647,041
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
filepath="Checkpoint_mejores_pesos_señal_ltlos_S2_lstm_stacked.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_mean_absolute_percentage_error', verbose=1, save_best_only=True, mode='min')
# simple early stopping
es = EarlyStopping(monitor='val_mean_absolute_percentage_error', mode='min', verbose=1, patience=5)

# %%
batch_size= 32 
epochs= 30
start = time.time()
History_ltlos2_lstm_stacked = model.fit(trainX, trainY,batch_size=batch_size, epochs= epochs, callbacks=[es, checkpoint] , validation_split=0.1)
print("> Compilation Time : ", time.time() - start)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 151602 samples, validate on 16845 samples
# Epoch 1/30
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 151602/151602 [==============================] - 70s 464us/step - loss: 0.0016 - mean_absolute_percentage_error: 4924.1802 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0155 - val_loss: 2.2284e-04 - val_mean_absolute_percentage_error: 1.5850 - val_mean_squared_error: 2.2284e-04 - val_mean_absolute_error: 0.0147
#
# Epoch 00001: val_mean_absolute_percentage_error improved from inf to 1.58500, saving model to Checkpoint_mejores_pesos_señal_ltlos_S2_lstm_stacked.hdf5
# Epoch 2/30
# 151602/151602 [==============================] - 60s 396us/step - loss: 2.1740e-04 - mean_absolute_percentage_error: 1142.9618 - mean_squared_error: 2.1740e-04 - mean_absolute_error: 0.0087 - val_loss: 1.8110e-05 - val_mean_absolute_percentage_error: 0.3754 - val_mean_squared_error: 1.8110e-05 - val_mean_absolute_error: 0.0035
#
# Epoch 00002: val_mean_absolute_percentage_error improved from 1.58500 to 0.37539, saving model to Checkpoint_mejores_pesos_señal_ltlos_S2_lstm_stacked.hdf5
# Epoch 3/30
# 151602/151602 [==============================] - 60s 393us/step - loss: 1.6558e-04 - mean_absolute_percentage_error: 1059.9973 - mean_squared_error: 1.6558e-04 - mean_absolute_error: 0.0076 - val_loss: 7.0821e-05 - val_mean_absolute_percentage_error: 0.8477 - val_mean_squared_error: 7.0821e-05 - val_mean_absolute_error: 0.0079
#
# Epoch 00003: val_mean_absolute_percentage_error did not improve from 0.37539
# Epoch 4/30
# 151602/151602 [==============================] - 59s 390us/step - loss: 1.3367e-04 - mean_absolute_percentage_error: 1250.6290 - mean_squared_error: 1.3367e-04 - mean_absolute_error: 0.0068 - val_loss: 2.9150e-05 - val_mean_absolute_percentage_error: 0.5040 - val_mean_squared_error: 2.9150e-05 - val_mean_absolute_error: 0.0046
#
# Epoch 00004: val_mean_absolute_percentage_error did not improve from 0.37539
# Epoch 5/30
# 151602/151602 [==============================] - 59s 387us/step - loss: 1.2106e-04 - mean_absolute_percentage_error: 787.8372 - mean_squared_error: 1.2106e-04 - mean_absolute_error: 0.0066 - val_loss: 2.6472e-05 - val_mean_absolute_percentage_error: 0.4683 - val_mean_squared_error: 2.6472e-05 - val_mean_absolute_error: 0.0043
#
# Epoch 00005: val_mean_absolute_percentage_error did not improve from 0.37539
# Epoch 6/30
# 151602/151602 [==============================] - 59s 388us/step - loss: 1.1399e-04 - mean_absolute_percentage_error: 2260.9629 - mean_squared_error: 1.1399e-04 - mean_absolute_error: 0.0062 - val_loss: 6.2637e-05 - val_mean_absolute_percentage_error: 0.8012 - val_mean_squared_error: 6.2637e-05 - val_mean_absolute_error: 0.0075
#
# Epoch 00006: val_mean_absolute_percentage_error did not improve from 0.37539
# Epoch 7/30
# 151602/151602 [==============================] - 59s 390us/step - loss: 1.1184e-04 - mean_absolute_percentage_error: 1229.0025 - mean_squared_error: 1.1184e-04 - mean_absolute_error: 0.0061 - val_loss: 4.2528e-06 - val_mean_absolute_percentage_error: 0.1745 - val_mean_squared_error: 4.2528e-06 - val_mean_absolute_error: 0.0016
#
# Epoch 00007: val_mean_absolute_percentage_error improved from 0.37539 to 0.17448, saving model to Checkpoint_mejores_pesos_señal_ltlos_S2_lstm_stacked.hdf5
# Epoch 8/30
# 151602/151602 [==============================] - 60s 398us/step - loss: 1.0098e-04 - mean_absolute_percentage_error: 907.5362 - mean_squared_error: 1.0098e-04 - mean_absolute_error: 0.0058 - val_loss: 9.2490e-06 - val_mean_absolute_percentage_error: 0.2642 - val_mean_squared_error: 9.2490e-06 - val_mean_absolute_error: 0.0024
#
# Epoch 00008: val_mean_absolute_percentage_error did not improve from 0.17448
# Epoch 9/30
# 151602/151602 [==============================] - 60s 396us/step - loss: 9.7927e-05 - mean_absolute_percentage_error: 1128.5970 - mean_squared_error: 9.7927e-05 - mean_absolute_error: 0.0058 - val_loss: 5.4590e-05 - val_mean_absolute_percentage_error: 0.7423 - val_mean_squared_error: 5.4590e-05 - val_mean_absolute_error: 0.0069
#
# Epoch 00009: val_mean_absolute_percentage_error did not improve from 0.17448
# Epoch 10/30
# 151602/151602 [==============================] - 59s 388us/step - loss: 9.5875e-05 - mean_absolute_percentage_error: 822.9546 - mean_squared_error: 9.5875e-05 - mean_absolute_error: 0.0058 - val_loss: 1.0105e-04 - val_mean_absolute_percentage_error: 1.0501 - val_mean_squared_error: 1.0105e-04 - val_mean_absolute_error: 0.0097
#
# Epoch 00010: val_mean_absolute_percentage_error did not improve from 0.17448
# Epoch 11/30
# 151602/151602 [==============================] - 62s 407us/step - loss: 9.6334e-05 - mean_absolute_percentage_error: 1715.0673 - mean_squared_error: 9.6334e-05 - mean_absolute_error: 0.0058 - val_loss: 5.6389e-05 - val_mean_absolute_percentage_error: 0.7032 - val_mean_squared_error: 5.6389e-05 - val_mean_absolute_error: 0.0066
#
# Epoch 00011: val_mean_absolute_percentage_error did not improve from 0.17448
# Epoch 12/30
# 151602/151602 [==============================] - 60s 393us/step - loss: 9.5191e-05 - mean_absolute_percentage_error: 970.9820 - mean_squared_error: 9.5191e-05 - mean_absolute_error: 0.0057 - val_loss: 2.1245e-05 - val_mean_absolute_percentage_error: 0.4297 - val_mean_squared_error: 2.1245e-05 - val_mean_absolute_error: 0.0040
#
# Epoch 00012: val_mean_absolute_percentage_error did not improve from 0.17448
# Epoch 00012: early stopping
# > Compilation Time :  728.6787369251251

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model_ltlos_señal2_lstm_stacked.json", "w") as json_file:
    json_file.write(model_json)

# %%
import pickle

pickle_out = open("History_ltlos2_lstm_stacked.pickle","wb")
pickle.dump(History_ltlos2_lstm_stacked, pickle_out)
pickle_out.close()

# %%
import pickle 

pickle_in = open("History_ltlos2_lstm_stacked.pickle","rb")
History_saved = pickle.load(pickle_in)

# %%
History = History_saved

# %%
# plot metrics
#plt.figure(figsize=[8,8])
plt.plot(History.history['mean_squared_error'], label='mse')
plt.plot(History.history['val_mean_squared_error'], label= 'validación_mse')
plt.xlabel("epocas",fontsize = 16)
plt.ylabel("loss",fontsize = 16)
plt.legend(framealpha=1, frameon=True)

# %%
plt.plot(History.history['mean_absolute_error'], label='mae')
plt.plot(History.history['val_mean_absolute_error'], label= 'validación_mae')
plt.xlabel("epocas",fontsize = 16)
plt.ylabel("loss",fontsize = 16)
plt.legend(framealpha=1, frameon=True)

# %%
#History.history['mean_absolute_percentage_error']

# %%
plt.plot(History.history['mean_absolute_percentage_error'], label= 'mape')
plt.plot(History.history['val_mean_absolute_percentage_error'], label= 'validación_mape')
plt.xlabel("epocas",fontsize = 16)
plt.ylabel("loss",fontsize = 16)
plt.legend(framealpha=1, frameon=True)

# %%
# predicciones de los valores de prueba
prediccion_test = model.predict(testX)
prediccion_test = scaler.inverse_transform(prediccion_test)
#actuals = test_y
valor_real_test = scaler.inverse_transform([testY])
valor_real_test= valor_real_test.reshape(len(prediccion_test),1)
#prediccion de los valores de entrenamiento
aprendido=model.predict(trainX)
aprendido_train=scaler.inverse_transform(aprendido)
reales_train=scaler.inverse_transform([trainY])
reales_train=scaler.inverse_transform([trainY])
reales_train=reales_train.reshape(len(aprendido),1)
###################################################
mse_aprendido=mean_squared_error(reales_train,aprendido_train)
mse_test=mean_squared_error(valor_real_test,prediccion_test)
print('Train Mean square Error:', mse_aprendido)
print('Test Mean square Error:', mse_test)
#######################################################
rmse_train=math.sqrt(mse_aprendido)
rmse_test=math.sqrt(mse_test)
print('Train Root Mean Squared Error:', rmse_train)
print('Test Root Mean Squared Error:', rmse_test)
# Out:
# Train Mean square Error: 0.14388327141328633
# Test Mean square Error: 0.16095768236491098
# Train Root Mean Squared Error: 0.37931948462119147
# Test Root Mean Squared Error: 0.401195316977792

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
#mape train
mean_absolute_percentage_error(reales_train,aprendido_train)
# Out:
# 3.6006195179343505

# %%
#mape test
mean_absolute_percentage_error(valor_real_test,prediccion_test)
# Out:
# 3.232693837673813

# %%
def smape(y_true, y_pred):
    denominator = (np.abs(y_true) + np.abs(y_pred))
    diff = np.abs(y_true - y_pred) / denominator
    diff[denominator == 0] = 0.0
    return 200 * np.mean(diff)

# %%
smape(reales_train,aprendido_train)
# Out:
# 3.5206678001011413

# %%
smape(valor_real_test,prediccion_test)
# Out:
# 3.165592084586777

# %%
# plot entrenamiento
plt.figure(figsize=[12,12])
plt.plot(reales_train, label='Datos reales')
plt.plot(aprendido_train, label= 'predicciones aprendido')
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.legend(framealpha=1, frameon=True, loc='upper right')

# %%
# plot test
plt.figure(figsize=[12,12])
plt.plot(valor_real_test, label='Datos reales')
plt.plot(prediccion_test , label= 'predicciones test')
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.legend(framealpha=1, frameon=True, loc='upper right')

# %%
# plot test
plt.figure(figsize=[12,12])
plt.plot(valor_real_test[22000:22500], label='Datos reales')
plt.plot(prediccion_test[22000:22500], label= 'predicciones test')
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.legend(framealpha=1, frameon=True, loc='upper right')

# %%
acc = abs(prediccion_test-valor_real_test)
porc_error = (acc / abs(valor_real_test)) * 100
mostrar = valor_real_test, prediccion_test, acc, porc_error
Tabla_arr = np.array(mostrar)
Tabla = np.transpose(Tabla_arr)
Tabla=Tabla.reshape(len(acc), -1)
Tabla_df = pd.DataFrame(Tabla, columns=['Datos predichos','Datos reales','Error','Error porcentual'])
Tabla_df
# Out:
#        Datos predichos  Datos reales     Error  Error porcentual
# 0                -6.49     -6.873175  0.383175          5.904085
# 1                -6.49     -6.850379  0.360379          5.552828
# 2                -6.49     -6.843488  0.353488          5.446652
# 3                -6.49     -6.836946  0.346946          5.345855
# 4                -6.49     -6.844909  0.354909          5.468547
# ...                ...           ...       ...               ...
# 42011            -9.30     -9.184678  0.115322          1.240021
# 42012            -9.30     -9.168692  0.131308          1.411918
# 42013            -9.15     -9.185630  0.035630          0.389397
# 42014            -9.00     -9.117449  0.117449          1.304987
# 42015            -8.71     -9.047215  0.337215          3.871579
#
# [42016 rows x 4 columns]

# %%
import seaborn as sns

# %%
aprendido_red=aprendido_train[:,0]
rial=reales_train[:,0]
testing=valor_real_test[:,0]
prediccion=prediccion_test[:,0]

# %%
sns.kdeplot(aprendido_red, cumulative=True)
sns.kdeplot(rial, cumulative=True)

# %%
err_apre=aprendido_train-reales_train
err_2=err_apre[:,0]
sns.kdeplot(err_2, cumulative=True)

# %%
sns.kdeplot(testing, cumulative=True)
sns.kdeplot(prediccion, cumulative=True)

# %%
err=prediccion_test-valor_real_test
err_1=err[:,0]
sns.kdeplot(err_1, cumulative=True)

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(POT2)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(aprendido_train)+look_back, :] = aprendido_train
# shift test predictions for plotting
testPredictPlot = np.empty_like(POT2)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(aprendido_train)+(look_back*2)+1:len(POT2)-1, :] = prediccion_test
# plot baseline and predictions
plt.figure(figsize=[12,12])
plt.plot((POT))
plt.plot(trainPredictPlot, color="red", )
plt.xlabel("muestras",fontsize = 20)
plt.ylabel("Potencia",fontsize = 20)
plt.plot(testPredictPlot, color="green")
plt.title("Predicciones de lo aprendido en rojo y verde en prueba", fontsize = 20)
plt.grid()
plt.show()

# %%
adqw=trainPredictPlot+testPredictPlot
